# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from urllib.parse import urljoin

# %%
website = 'https://www.yellowpages.ca/search/si/1/Restaurants/London+ON'

# %%
response = requests.get(website)

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ### Results

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html class="no-js critical-off" lang="en-CA" xml:lang="en-CA" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"498849646",accountID:"824834",trustKey:"45968",xpid:"XAQDWVVXGwcJXFlSAgQPUg==",licenseKey:"d901b4dcbe",applicationID:"498805584"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b=" ...
# .side-menu{position:fixed;top:0;overflow:auto;width:280px;height:100%;z-index:202}.side-menu.side-menu--left{left:-280px;transition:left .5s ease}.side-menu--left--open .side-menu.side-menu--left.side-menu--left{left:0;box-shadow:1px 2px 4px rgba(0,0,0,.2)}.side-menu.side-menu--right{right:-280px;transition:right .5s ease}.side-menu--right--open .side-menu.side-menu--right.side-menu--right{right:0;z-index:1001}.side-menu.side-menu--mobile{right:-280px;transition:right .5s ease}.side-menu--mobile--open .side-menu.side-menu--mobile.side-menu--mobile{right:15px;z-index:1001}.overlay__container{display:none}.hidden{display:none!important}.upcase{text-transform:uppercase}.hide-text{text-indent:100%;white-space:nowrap;overflow:hidden;position:absolute}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.visuallyhidden{position:absolute;overflow:hidden;clip:rect(0 0 0 0);height:1px;width:1px;margin:-1px;padding:0;border:0}.quote__after{text-decoration:none}.quote__after:after{content:' \00BB '}.quote__before{text-decoration:none}.quote__before:before{content:'\00AB '}.v-hidden{visibility:hidden}body,html{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline}html{line-height:1}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font:inherit;font-size:100%;vertical-align:baseline}ol,ul{list-style:none}table{border-collapse:collapse;border-spacing:0}caption,td,th{text-align:left;vertical-align:middle}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}a img{border:none}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section,summary{display:block}body,html{width:100%;height:100%;background-color:#f3f3f3}body{font-family:"YP Local",sans-serif;font-size:90%;color:#333;font-weight:100;line-height:140%;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}*,:after,:before{box-sizing:border-box}a{text-decoration:underline;color:#333}a:hover{text-decoration:none}.italic,em,i{font-style:italic}b,strong{font-weight:300}input{font-weight:100}button,input{font-family:"YP Local",sans-serif}::selection{color:#333;background-color:#ffcd00}input[type=text]::-ms-clear{display:none}figure{margin:0}form{margin:0}button{border:0;margin:0;padding:0;cursor:pointer}address{font-style:normal}ul{padding:0;margin:0;list-style:none}.page__wrapper{display:-ms-flexbox;display:flex;-ms-flex-align:stretch;align-items:stretch;-ms-flex-negative:0;flex-shrink:0;-ms-flex-direction:column;flex-direction:column;margin:0;padding:0;height:100%}#cobrand .page__wrapper{height:calc(100vh - 88px)}.page__footer,.page__header{-ms-flex:0 0 auto;flex:0 0 auto}.page-CONTACT_US .page__header,.page-MERCHANT_DIRECTIONS .page__header{margin-bottom:10px}.ypg_mediative_smart_tips{margin-bottom:20px;display:-ms-flexbox;display:flex;-ms-flex-pack:center;justify-content:center}.ypg_mediative_smart_tips>div{overflow:hidden}.page__container{-ms-flex:1 0 auto;flex:1 0 auto}@media (min-width:851px){.page__container:not(.page__container--mapview) .page__sidebar{width:296px}}@media (min-width:600px){.page__container .page__sidebar--left{margin-right:20px}}@media (min-width:851px){.page__container .page__sidebar--right{margin-left:50px;padding-top:72px}}.page__container .page__content-wrap{margin-bottom:30px;background-color:#fff;border-radius:2px;box-shadow:0 2px 2px -1px rgba(0,0,0,.2);line-height:130%}.page__container .page__content-wrap:after,.page__container .page__content-wrap:before{content:" ";display:table}.page__container .page__content-wrap:after{clear:bo ...
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowJQuery.js" type="text/javascript"></script><!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M3TSKZ2');</script>
# <!-- End Google Tag Manager -->
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/baseYellow_core.js" type="text/javascript"></script><meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">(function(){var c = document.getElementsByTagName('html')[0];c.className = c.className.replace(/no-js/, 'js');})()</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="none" name="msapplication-config">
# <meta content="initial-scale=1.0, maximum-scale=1.0, width=device-width" name="viewport"/>
# <meta content="#FFCD00" name="theme-color"/>
# <meta content="#FFCD00" name="msapplication-navbutton-color"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="Origin" name="referrer"/>
# <meta content="en-CA" name="DC.Language">
# <title>The Best Restaurants in London | YellowPages.ca™</title>
# <meta content="Locate and compare Restaurants in London ON, Yellow Pages Local Listings. Find useful information, the address and the phone number of the local business you are looking for." name="description">
# <meta content="com.ypg.yellowpages://serp?what=Restaurants&amp;where=London+ON" property="al:ios:url">
# <meta content="322964940" property="al:ios:app_store_id">
# <meta content="YP Yellow Pages Canada" property="al:ios:app_name"/>
# <meta content="com.ypg.find://www.yellowpages.ca/search/si/1/Restaurants/London+ON" property="al:android:url"/>
# <meta content="YP Yellow Pages Canada" property="al:android:app_name"/>
# <meta content="com.ypg.find" property="al:android:package"/>
# <meta content="https://www.yellowpages.ca/search/si/1/Restaurants/London+ON" property="al:web:url"/>
# <link href="https://www.yellowpages.ca/search/si/1/Restaurants/London+ON" hreflang="en-ca" rel="alternate"/>
# <link href="https://www.pagesjaunes.ca/search/si/1/Restaurants/London+ON" hreflang="fr-ca" rel="alternate"/>
# <link href="https://www.yellowpages.ca/search/si/1/Restaurants/London+ON" rel="canonical"/>
# <!-- all pages in this env -->
# <meta content="noarchive,index,follow" name="robots"/>
# <link href="android-app://com.ypg.find/http/www.yellowpages.ca/search/si/1/Restaurants/London+ON" rel="alternate"/>
# <meta content="1004441262966232" property="fb:app_id"/>
# <meta content="YellowPages.ca" property="og:site_name"/>
# <meta content="The Best Restaurants in London | YellowPages.ca™" property="og:title"/>
# <meta content="716482783,504830416,615841352" property="fb:admins"/>
# <meta content="https://www.yellowpages.ca/search/si/1/Restaurants/London+ON" property="og:url"/>
# <meta content="Locate and compare Restaurants in London ON, Yellow Pages Local Listings. Find useful information, the address and the phone number of the local business you are looking for." property="og:description"/>
# <script type="application/ld+json">
# {"dateModified":"2022-09-12","description":"Complete list of best Restaurants in London ON","name":"Restaurants in London ON","@type":"DataFeedItem","@context":"http://schema.org"}</script>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.eot?e1cvpc" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.ttf?e1cvpc" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.woff?e1cvpc" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.svg?e1cvpc#ypca-icons" rel="preload"/>
# <link as="style" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowMapsModule_osm.css" rel="preload"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//static.yellowpages.ca" rel="dns-prefetch"/>
# <link href="//cdn.tile.yellowpages.ca" rel="dns-prefetch"/>
# <link href="//ssvs.yp.ca" rel="dns-prefetch"/>
# <link href="//cdn.media.yp.ca" rel="dns-prefetch"/>
# <link href="//cdn.ci.yp.ca" rel="dns-prefetch"/>
# <link href="//ssmscdn.yp.ca" rel="dns-prefetch"/>
# <link href="//static.cms.yp.ca" rel="dns-prefetch"/>
# <link href="//cdn.cb.yp.ca" rel="dns-prefetch"/>
# <link href="//api.amplitude.com" rel="dns-prefetch"/>
# <link href="//static.criteo.net" rel="dns-prefetch"/>
# <link href="//bam.nr-data.net" rel="dns-prefetch"/>
# <link href="//gum.criteo.com" rel="dns-prefetch"/>
# <link href="//984-yin-134.mktoresp.com" rel="dns-prefetch"/>
# <link href="//logger.yp.ca" rel="dns-prefetch"/>
# <link href="//as-sec.casalemedia.com" rel="dns-prefetch"/>
# <link href="//sb.scorecardresearch.com" rel="dns-prefetch"/>
# <link href="//secure.adnxs.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//adservice.google.ca" rel="dns-prefetch"/>
# <link href="//adservice.google.com" rel="dns-prefetch"/>
# <link href="//cdn.krxd.net" rel="dns-prefetch"/>
# <link href="//cdn.districtm.io" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//www.googleadservices.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://www.yellowpages.ca/search/si/1/Restaurants/London+ON?format=georss" rel="Alternate" title="YellowPages.ca - Search Results for Restaurants in London ON" type="application/rss+xml">
# <script type="text/javascript">function logRequest(){try{var t;if(window.XMLHttpRequest)t=new XMLHttpRequest;else if(window.ActiveXObject)try{t=new ActiveXObject("Msxml2.XMLHTTP")}catch(e){try{t=new ActiveXObject("Microsoft.XMLHTTP")}catch(e){}}t&&(t.open("GET","/ajax/utilities/frame?referrer="+document.referrer,!0),t.send())}catch(e){}};function checkIfWhiteListed(){var obj=[".*urbanizer.yp.ca.*",".*urbanizer.ca.*",".*urbanizer.qa.yp.ca.*",".*urbanizer.com.*"];var testurl="";if(this.top.location!==this.location){testurl=document.referrer}else{testurl=this.top.location}for(var i=0;i<obj.length;i++){if(new RegExp(obj[i]).test(testurl)){return true}}return false};this.top.location!==this.location&&!checkIfWhiteListed()&&(logRequest(),this.top.location=this.location);</script>
# <link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/criticalSerpDesktop.css" rel="stylesheet" type="text/css"><style>
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Book.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Book.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Book.ttf') format('truetype');
# font-weight: 100;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.ttf') format('truetype');
# font-weight: 300;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.ttf') format('truetype');
# font-weight: 600;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.ttf') format('truetype');
# font-style: italic;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Hand';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.ttf') format('truetype');
# font-weight: normal;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'yp-icons';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.ttf') format('truetype');
# font-weight: normal;
# font-style: normal;
# font-display: swap;
# }
# </style>
# <!-- Is it Defer? no -->
# <link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowSerp.css" rel="stylesheet" type="text/css"><meta content="www.yellowpages.ca;6.69.0.0 (rev 20220823.0703);ProdYPAWS01" name="info">
# <script type="text/javascript">
# var aJsFiles = [];
# </script>
# </meta></link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body class="ypg ypg_search lang-en deviceDesktop jsDeviceDesktop page-SERP context-dine nearMeOn searchBodyClass notLoggedIn">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3TSKZ2" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="overlay__container jsOverlayContainer"></div>
# <div class="page__wrapper ypgBody" id="ypgBody">
# <script class="jsGenericRedirectConfig" type="application/json">
# {
# "redirect": false,
# "url": ""
# }
# </script>
# <div class="page__header jsHeader" id="ypg_Header">
# <header class="ypg-header jsHeaderWrapper">
# <div class="ypg-header__root">
# <div class="ypg-header__holder jsHeaderHolder">
# <div class="ypg-header__wrapper yp-header__wrapper__home">
# <div class="action-bar">
# <div class="action-bar__left ypg-header-left">
# <div class="ypg-logo">
# <a data-analytics='{"lk_pos":"header","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"header","lk_name":"yplogo"}' data-qa="QAypLogoLhs" href="/" id="QAypLogoLhs" title="Yellowpages.ca Canadian Business Directory - Meet the New Neighbourhood"><img alt="Visit YP.ca to search for businesses in Canada" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/images/verticals/yellowpages/logo-en.svg"/></a>
# </div>
# </div>
# <div class="action-bar__form search-form mobileSearch__form home_header_search_form jsUpdateBptnUser">
# <div class="action-bar__close"><button class="jsCloseSearch"><span class="ypicon ypicon-newx"></span></button></div>
# <form accept-charset="UTF-8" class="inputForm ypg-searchform jsSearchForm" data-action="/search/si/1/{{what}}/{{where}}" data-analytics='{"lk_pos":"top","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top","lk_name":"find"}' data-analytics-event="submit" data-search-type="business" id="inputForm" method="get" name="findform">
# <input id="latitude" name="latitude" type="hidden"/>
# <input id="longitude" name="longitude" type="hidden"/>
# <input id="mobiCode" name="mobiCode" type="hidden"/>
# <input id="sflag" name="sflag" type="hidden"/>
# <div class="inputFormWhat inputWrap search-form__item jsToolTipSpecifiDish jsSearchWhatWrapper">
# <div class="search-field-outer jsSearchWhatInner" id="searchwhat">
# <label class="sr-only" for="whatwho">Please enter what you're searching for</label>
# <input autocomplete="off" class="search-field typeahead height40" data-default="What? (E.g. cuisine, meal)" id="whatwho" maxlength="100" name="what" placeholder="What? (E.g. cuisine, meal)" required="required" size="100" type="text" value="Restaurants"/>
# </div>
# </div>
# <div class="searchFormMobileDisplay">
# <div class="inputFormWhere inputWrap search-form__item jsSearchWhereWrapper">
# <div class="search-field-outer jsToolTipNearMe search-field__previouslocation" id="searchwhere">
# <label class="sr-only" for="where">Please enter your search location</label>
# <input autocomplete="off" class="search-field typeahead height40" data-default="Where? (E.g. Toronto)" data-geoip-location="Toronto, ON" data-location="London ON" id="where" maxlength="250" name="where" placeholder="Where? (E.g. Toronto)" required="required" size="250" type="text" value="London ON"/>
# <span class="ypicon ypicon-curloc search-field--icon jsIconCurloc hidden"></span>
# <input autocomplete="off" class="search-field search-field--mask hidden jsWhere height40" data-default="Where? (E.g. Toronto)" data-geoip-location="Toronto, ON" data-location="London ON" maxlength="250" placeholder="Where? (E.g. Toronto)" size="100" type="text" value="Near me"/>
# </div>
# </div>
# <div class="actionWrap search-form__item">
# <div class="inputFormFind">
# <button class="search-form__button jsBtnSearchForm height40" name="search_button" title="Find." type="submit">
# <span class="search__icon"></span>
# <span class="visuallyhidden">Search</span>
# </button>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="linksHeader">
# <ul class="ypg-connect ypg-header-right_menu header-links ypg-connect--login jsConnectInfos">
# <li><a class="jsConnectButton" data-modal-url="/ajax/user/signin" data-qa="QAsignInLink" data-target="#jsModalContainer" data-toggle="ajax-modal">Log in</a></li>
# <li class="upcase">
# <a class="jsOtherLanguageUrl" data-analytics='{"lk_pos":"header","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"header","lk_name":"toggle_en"}' href="https://www.pagesjaunes.ca/search/si/1/Restaurants/London+ON?theme=dine" title="Visit Yellow Pages in French">
# fr<span class="visuallyhidden">Passer en français / Switch to French language</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <ul class="popular-links-serp">
# <li><a class="jsQuickLinks" data-analytics-placeholder='{"event_name":"click - Popular Heading - Placeholder","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"Popular_Heading_Placeholder"}' data-linksname="Restaurants" data-tagname="Restaurants" href="/search/si/1/Restaurants/London+ON">Restaurants</a></li>
# <li><a class="jsQuickLinks" data-analytics-placeholder='{"event_name":"click - Popular Heading - Placeholder","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"Popular_Heading_Placeholder"}' data-linksname="Dentists" data-tagname="Dentists" href="/search/si/1/Dentists/London+ON">Dentists</a></li>
# <li><a class="jsQuickLinks" data-analytics-placeholder='{"event_name":"click - Popular Heading - Placeholder","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"Popular_Heading_Placeholder"}' data-linksname="Medical Clinics" data-tagname="Medical Clinics" href="/search/si/1/Medical+Clinics/London+ON">Medical Clinics</a></li>
# <li><a class="jsQuickLinks" data-analytics-placeholder='{"event_name":"click - Popular Heading - Placeholder","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"Popular_Heading_Placeholder"}' data-linksname="Car Repair" data-tagname="Car Repair" href="/search/si/1/Car+Repair/London+ON">Car Repair</a></li>
# <li><a class="jsQuickLinks" data-analytics-placeholder='{"event_name":"click - Popular Heading - Placeholder","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"Popular_Heading_Placeholder"}' data-linksname="Grocery Stores" data-tagname="Grocery Stores" href="/search/si/1/Grocery+Stores/London+ON">Grocery Stores</a></li>
# </ul>
# </div>
# </div>
# </div>
# </header>
# <div class="ypalert ypalert--success authenticated--user--alert jsAlertBox jsAlertBoxUserConfirmed hidden">
# <button aria-hidden="true" class="close jsCloseAlert" type="button">×</button>
# Your account is now active!</div>
# <div class="ypg-cover hide-print">
# <span class="cover-image jsBanner"></span>
# </div>
# </div>
# <script class="jsMapsApiConfig" id="mapsAPI" type="application/json">
# {
# "mapProvider": "osm",
# "mapApiSrc" : "",
# "mapApiId" : "",
# "mapApiKey" : "",
# "mapLanguage" : "en-CA",
# "mapApiModuleSrc": [],
# "mapTiles" : "//cdn.tile.yellowpages.ca/osm/{z}/{x}/{y}.png"
# }
# </script>
# <div class="page__container jsTabsContent page__container--right-sidebar hasMap">
# <div class="page__container_wrap">
# <div class="page__content jsListingMerchantCards jsListContainer" id="jsListingMerchantCards">
# <div class="header__socialSearch">
# <h1 class="page__container-title"><strong>Restaurants</strong> in <strong>London ON</strong><span class="resultCount">
# (1065 Result(s))</span>
# </h1>
# <div class="filters__right">
# <div class="filter__item filter__item--more filter__item--sort">
# <a class="filter__item__cta jsFilterCta" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"sort"}' data-label="Sort by: " data-qa="filter-sort" href="#"><strong>Relevance</strong><span class="filter__arrow"></span></a>
# <div class="filter-sort__submenu__root jsSortByWrap">
# <ul class="filter__submenu jsSort" data-qa="filter-sort-list" data-sort="relevancy" data-url="/search/si/1/Restaurants/London+ON">
# <li class="jsTriggerNearMe">
# <span class="suggested-location__list__item--loading jsLoading"></span>
# <a href="javascript:void(0)">Closest</a>
# </li>
# <li>
# <a data-qa="filter_rating" href="/search/si/1/Restaurants/London+ON?sortby=rat" rel="nofollow">Highest rated</a>
# </li>
# <li>
# <a data-qa="filter_review" href="/search/si/1/Restaurants/London+ON?sortby=rev" rel="nofollow">Most reviewed</a>
# </li>
# <li>
# <a data-qa="filter_alpha" href="/search/si/1/Restaurants/London+ON?sortby=alph">Alphabetical</a>
# </li>
# <li>
# <a data-qa="filter_recentReview" href="/search/si/1/Restaurants/London+ON?sortby=recrev">Recently Reviewed</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="jsSocialSearchResult hidden social-search__container" id="socialSearchResult"></div>
# <a class="refine-results jsRefineResults" href="javascript:void(0)"><span class="text">Filters</span><span class="ypicon ypicon-newx"></span></a>
# <div class="tabs-wrapper filter__wrap searchContent">
# <div class="filter__tabcontainer jsSearchContent active">
# <script id="filter-resource" type="application/json">
# {
# "yp_ajaxUrl": "/ajax/filter/search/Restaurants/London+ON"
# }
# </script>
# <div class="filtersWrap filterToggle filters__root jsFiltersWrap">
# <div class="loader"></div>
# <div class="filterzView">
# <div class="filters">
# <div class="filters__left">
# <ul class="filters__menu jsFiltersMenu filters__menu--show-button">
# <li class="filter__item filter__item--content jsFilterButtons jsFilterTopBtn" data-analytics='{"lk_pos":"top_hidden","event_name":"Click - Filters - Online Shopping","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refineonlineshopping"}' data-encode="true" data-param="isOnlineShopping" data-placement="top" data-toggle="tooltip" title="Shop Online">
# <a class="filter__item__cta" href="/search/si/1/Restaurants/London+ON?filter=isOnlineShopping" rel="nofollow">
# <span class="social-search__switch__notification-little"></span>
# Shop Online</a>
# </li>
# <li class="filter__item filter__item--featureTypes filter__item--more jsFilterButtons jsFilterCustomAnalytics jsFilterTitle" data-analytics-placeholder='{"lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"features"}'>
# <a class="filter__item__cta jsFilterCta" data-qa="filter-featureTypes" href="#">
# Features<strong class="filer__count jsCount"></strong>
# <span class="filter__arrow"></span>
# </a>
# <div class="filter__submenu__root jsFilterVisible">
# <div class="featureTypes jsFeatureTypeWrap">
# <div class="filter__title">Features</div>
# <ul class="filter__submenu jsFilterItems" data-qa="filter-category-list">
# <li data-encode="true" data-param="ftr-1644-Restaurant+With+Parking" data-value="Parking">
# <a href="/search/si/1/Restaurants/London+ON?rfn=ftr-1644-Restaurant+With+Parking" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Parking</a>
# </li>
# <li data-encode="true" data-param="ftr-496-Wheelchair-accessible+Restaurant" data-value="Wheelchair-access">
# <a href="/search/si/1/Restaurants/London+ON?rfn=ftr-496-Wheelchair-accessible+Restaurant" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Wheelchair-access</a>
# </li>
# <li data-encode="true" data-param="ftr-1729-Restaurant+With+Wifi+Internet" data-value="Wi-Fi">
# <a href="/search/si/1/Restaurants/London+ON?rfn=ftr-1729-Restaurant+With+Wifi+Internet" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Wi-Fi</a>
# </li>
# </ul>
# </div>
# <a class="loadmore clicked" href="javascript:void(0);">
# <span class="loadingMoreResults"></span>
# </a>
# <div class="filters__submenu__footer jsFilterBtns">
# <div class="filters__footer__switch"></div>
# <div class="filters__footer__buttons">
# <button class="ypbtn btn-theme jsBtnApply btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refine"}' data-qa="filter-apply" disabled="disabled" type="button">Apply</button>
# <a class="ypbtn btn-link filters__clear jsBtnClear hidden btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"clear"}' data-qa="filter-clear" href="#">
# <span class="content">Clear</span>
# </a>
# <button class="jsBtnClose filters__close" data-qa="filter-close" title="Close" type="button"><span class="ypicon ypicon-newx"></span></button>
# </div>
# </div>
# </div>
# </li>
# <li class="filter__item filter__item--cuisineTypes filter__item--more jsFilterButtons jsFilterCustomAnalytics jsFilterTitle" data-analytics-placeholder='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"cuisine"}'>
# <a class="filter__item__cta jsFilterCta" data-qa="filter-cuisineTypes" href="#">Cuisine<strong class="filer__count jsCount"></strong><span class="filter__arrow"></span></a>
# <div class="filter__submenu__root jsFilterVisible">
# <div class="cuisineTypes jsCuisineTypeWrap">
# <div class="filter__title">Select the type(s) of food you’re looking for.</div>
# <ul class="filter__submenu jsFilterItems" data-qa="filter-category-list">
# <li data-encode="true" data-param="rcu-708" data-value="American Cuisine">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-708" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>American Cuisine</a>
# </li>
# <li data-encode="true" data-param="rcu-853" data-value="Asian">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-853" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Asian</a>
# </li>
# <li data-encode="true" data-param="rcu-1537" data-value="Brunch">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-1537" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Brunch</a>
# </li>
# <li data-encode="true" data-param="rcu-1760" data-value="Canadian Cuisine">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-1760" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Canadian Cuisine</a>
# </li>
# <li data-encode="true" data-param="rcu-2283" data-value="Chinese">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-2283" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Chinese</a>
# </li>
# <li data-encode="true" data-param="rcu-2604" data-value="Continental">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-2604" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Continental</a>
# </li>
# <li data-encode="true" data-param="rcu-727" data-value="French">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-727" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>French</a>
# </li>
# <li data-encode="true" data-param="rcu-851" data-value="Fusion">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-851" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Fusion</a>
# </li>
# <li data-encode="true" data-param="rcu-2345" data-value="Indian">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-2345" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Indian</a>
# </li>
# <li data-encode="true" data-param="rcu-13235" data-value="International">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-13235" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>International</a>
# </li>
# <li data-encode="true" data-param="rcu-2595" data-value="Italian">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-2595" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Italian</a>
# </li>
# <li data-encode="true" data-param="rcu-2623" data-value="Japanese">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-2623" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Japanese</a>
# </li>
# <li data-encode="true" data-param="rcu-2798" data-value="Korean">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-2798" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Korean</a>
# </li>
# <li data-encode="true" data-param="rcu-3064" data-value="Lebanese">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-3064" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Lebanese</a>
# </li>
# <li data-encode="true" data-param="rcu-3437" data-value="Mediterranean">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcu-3437" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>Mediterranean</a>
# </li>
# </ul></div>
# <a class="loadmore clicked" href="javascript:void(0);">
# <span class="loadingMoreResults"></span>
# </a>
# <div class="filters__submenu__footer jsFilterBtns">
# <div class="filters__footer__switch"></div>
# <div class="filters__footer__buttons">
# <button class="ypbtn btn-theme jsBtnApply btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refine"}' data-qa="filter-apply" disabled="disabled" type="button">Apply</button>
# <a class="ypbtn btn-link filters__clear jsBtnClear hidden btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"clear"}' data-qa="filter-clear" href="#">
# <span class="content">Clear</span>
# </a>
# <button class="jsBtnClose filters__close" data-qa="filter-close" title="Close" type="button"><span class="ypicon ypicon-newx"></span></button>
# </div>
# </div>
# </div>
# </li>
# <li class="filter__item filter__item--rates filter__item--more jsFilterButtons jsFilterCustomAnalytics jsFilterTitle" data-analytics-placeholder='{"lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"rates"}'>
# <a class="filter__item__cta jsFilterCta" data-qa="filter-rates" href="#">Rates<strong class="filer__count jsCount"></strong><span class="filter__arrow"></span></a>
# <div class="filter__submenu__root jsFilterVisible">
# <div class="rates jsRatesWrap">
# <div class="filter__title">Rates</div>
# <ul class="filter__submenu filter__submenu--rates jsFilterItems" data-qa="filter-category-list">
# <li data-encode="true" data-param="rra-pr01" data-value="&lt; $10">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rra-pr01" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>$</a>
# </li>
# <li data-encode="true" data-param="rra-pr02" data-value="$11 To $25">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rra-pr02" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>$$</a>
# </li>
# <li data-encode="true" data-param="rra-pr03" data-value="$26 To $60">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rra-pr03" rel="nofollow"><em class="ypicon ypicon-checkbox-empty"></em>$$$</a>
# </li>
# </ul></div>
# <a class="loadmore clicked" href="javascript:void(0);">
# <span class="loadingMoreResults"></span>
# </a>
# <div class="filters__submenu__footer jsFilterBtns">
# <div class="filters__footer__switch"></div>
# <div class="filters__footer__buttons">
# <button class="ypbtn btn-theme jsBtnApply btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refine"}' data-qa="filter-apply" disabled="disabled" type="button">Apply</button>
# <a class="ypbtn btn-link filters__clear jsBtnClear hidden btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"clear"}' data-qa="filter-clear" href="#">
# <span class="content">Clear</span>
# </a>
# <button class="jsBtnClose filters__close" data-qa="filter-close" title="Close" type="button"><span class="ypicon ypicon-newx"></span></button>
# </div>
# </div>
# </div>
# </li>
# <li class="filter__item filter__item--content jsFilterButtons jsFilterTopBtn" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refinereserveonline"}' data-encode="true" data-param="booking" data-placement="top" data-toggle="tooltip" title="Show businesses that offer online reservations.">
# <a class="filter__item__cta" href="/search/si/1/Restaurants/London+ON?filter=booking" rel="nofollow">Reserve Online</a>
# </li>
# <li class="filter__item filter__item--content jsFilterButtons jsFilterTopBtn" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refineopennow"}' data-encode="true" data-param="open" data-placement="top" data-toggle="tooltip" title="Show only businesses that are open now.">
# <a class="filter__item__cta" href="/search/si/1/Restaurants/London+ON?filter=open" rel="nofollow">Open now</a>
# </li>
# <li class="filter__item filter__item--content jsFilterButtons jsFilterTopBtn" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"open24"}' data-encode="true" data-param="open24Hours" data-placement="top" data-toggle="tooltip" title="Open 24hrs a day.">
# <a class="filter__item__cta" href="/search/si/1/Restaurants/London+ON?filter=open24Hours" rel="nofollow">24/7</a>
# </li>
# <li class="filter__item filter__item--neighbourhoods filter__item--more jsFilterButtons jsFilterCustomAnalytics jsFilterTitle jsToolTipLocation" data-analytics-placeholder='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"neighbourhoods"}'>
# <a class="filter__item__cta jsFilterCta" data-qa="filter-neighbourhoods" href="#">Neighbourhood<strong class="filer__count jsCount"></strong><span class="filter__arrow"></span></a>
# <div class="filter__submenu__root jsFilterSubmenu jsFilterVisible">
# <div class="neighbourhoods jsNeighborhoodWrap">
# <div class="filter__title">Pick the area(s) you’d like to see results in.</div>
# <ul class="filter__submenu jsFilterItems" data-qa="filter-neighbourhood-list">
# <li data-encode="true" data-param="rcn-5855259-Downtown-London" data-value="Downtown London">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcn-5855259-Downtown-London" rel="nofollow">
# <span><em class="ypicon ypicon-checkbox-empty"></em>Downtown London</span>
# </a>
# </li>
# <li data-encode="true" data-param="rcn-5860785-North-East-London" data-value="North East London">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcn-5860785-North-East-London" rel="nofollow">
# <span><em class="ypicon ypicon-checkbox-empty"></em>North East London</span>
# </a>
# </li>
# <li data-encode="true" data-param="rcn-12808733-North-West-London" data-value="North West London">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcn-12808733-North-West-London" rel="nofollow">
# <span><em class="ypicon ypicon-checkbox-empty"></em>North West London</span>
# </a>
# </li>
# <li data-encode="true" data-param="rcn-5861049-South-East-London" data-value="South East London">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcn-5861049-South-East-London" rel="nofollow">
# <span><em class="ypicon ypicon-checkbox-empty"></em>South East London</span>
# </a>
# </li>
# <li data-encode="true" data-param="rcn-12808787-South-West-London" data-value="South West London">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rcn-12808787-South-West-London" rel="nofollow">
# <span><em class="ypicon ypicon-checkbox-empty"></em>South West London</span>
# </a>
# </li>
# </ul>
# </div>
# <a class="loadmore clicked" href="javascript:void(0);">
# <span class="loadingMoreResults"></span>
# </a>
# <div class="filters__submenu__footer jsFilterBtns">
# <div class="filters__footer__switch">
# <a class="jsBtnShowSubMenu" href="#">
# <span class="postalCode" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"postalCode"}' data-tab="postalCode">Filter by postal code »</span>
# </a>
# </div>
# <div class="filters__footer__buttons">
# <button class="ypbtn btn-theme jsBtnApply btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"refine"}' data-qa="filter-apply" disabled="disabled" type="button">Apply</button>
# <a class="ypbtn btn-link filters__clear jsBtnClear hidden btn-sm" data-analytics='{"lk_pos":"top_hidden","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"top_hidden","lk_name":"clear"}' data-qa="filter-clear" href="#">
# <span class="content">Clear</span>
# </a>
# <button class="jsBtnClose filters__close" data-qa="filter-close" title="Close" type="button"><span class="ypicon ypicon-newx"></span></button>
# </div>
# </div>
# </div>
# <div class="filter__submenu__root filter__submenu__root--postalcode jsFilterSubmenu jsFilterVisible hidden" data-title="Filter by neighbourhood">
# <div class="postalcode jsPostalCodeWrap">
# <ul class="filter__submenu jsFilterItems" data-qa="filter-postalcode-list">
# <li data-encode="true" data-param="rpc-H1N" data-value="H1N">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-H1N">
# <span><em class="ypicon ypicon-checkbox-empty"></em>H1N</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-K2P" data-value="K2P">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-K2P">
# <span><em class="ypicon ypicon-checkbox-empty"></em>K2P</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-K8N" data-value="K8N">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-K8N">
# <span><em class="ypicon ypicon-checkbox-empty"></em>K8N</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-L1G" data-value="L1G">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-L1G">
# <span><em class="ypicon ypicon-checkbox-empty"></em>L1G</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-L1H" data-value="L1H">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-L1H">
# <span><em class="ypicon ypicon-checkbox-empty"></em>L1H</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-L5R" data-value="L5R">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-L5R">
# <span><em class="ypicon ypicon-checkbox-empty"></em>L5R</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-L8K" data-value="L8K">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-L8K">
# <span><em class="ypicon ypicon-checkbox-empty"></em>L8K</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N0E" data-value="N0E">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N0E">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N0E</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N0J" data-value="N0J">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N0J">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N0J</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N0L" data-value="N0L">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N0L">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N0L</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N0M" data-value="N0M">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N0M">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N0M</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N0N" data-value="N0N">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N0N">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N0N</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N0R" data-value="N0R">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N0R">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N0R</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N2G" data-value="N2G">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N2G">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N2G</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N2L" data-value="N2L">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N2L">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N2L</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N3V" data-value="N3V">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N3V">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N3V</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N4S" data-value="N4S">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N4S">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N4S</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N4V" data-value="N4V">
# <a href="/search/si/1/Restaurants/London+ON?rfn=rpc-N4V">
# <span><em class="ypicon ypicon-checkbox-empty"></em>N4V</span>
# </a>
# </li>
# <li data-encode="true" data-param="rpc-N4X" data-value="N4X">
# ...
# "general.next" : "Next",
# "general.prev" : "Prev",
# "home.time.minutes" : "minutes ago",
# "home.time.hours" : "hours ago",
# "home.time.days" : "days ago",
# "home.time.view" : "Viewed",
# "merchant.update.error" : "The content must be different  ",
# "merchant.update.minlength" : "Please enter 10 digits number",
# "merchant.update.required" : "The field is required",
# "merchant.update.email.valid" : "Please enter a valid email address."
#
# }
# </script>
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowFetchInject.js" type="text/javascript"></script><script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/baseYellow_critical.js" type="text/javascript"></script><script type="text/javascript">
# $YPCA.deferJsV2('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/baseYellow_defer.js');</script>
# <div aria-hidden="true" class="modal hide fade sensitiveModal jsModalSensitive" id="ypSensitiveHeading" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-md">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-title">You are now leaving YP.ca</div>
# </div>
# <div class="modal-body">
# <div class="content">
# <div class="ypalert ypalert--info jsAlertSensitiveContent">The site you are connecting to (<span></span>) is not published by YellowPages.ca™, so we cannot guarantee its availability or take responsibility for its content.</div>
# <p class="text-align-center">Do you wish to continue?</p>
# <div class="btns text-align-center">
# <button class="ypbtn btn-default btn-cancel jsBtnSensitiveCancel">NO</button>
# <button class="ypbtn btn-primary btn-goTo jsBtnSensitiveGoTo">YES</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="modalRateResults"></div>
# <div aria-hidden="true" aria-labelledby="ypBuyerTips" class="modal hide fade buyerTips buyerTipsModal jsBuyerTips" id="ypBuyerTips" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-title"></div>
# </div>
# <div class="modal-content">
# <div class="modal-body">
# <div class="content"></div>
# </div>
# </div>
# </div>
# </div>
# <script id="callIntercept_config" type="application/json">
# {
# "primary_heading" : "01125710",
# "location" : "London",
# "call_delay" : 0,
# "intercept_limit" : 1
# }
# </script>
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/monoScheduling.js" type="text/javascript"></script><script type="text/javascript">
# $YPCA.deferJsV2('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowSerp_defer.js');</script>
# <script id="serpDeals-resource" type="application/json">
# {
#
# "yp_currentLocText" : "Current location",
# "yp_errorLoc" : "Couldn't determine location",
# "yp_lang" : "en"
# }
# </script>
# <script class="jsViewMoreMobileConfig" type="application/json">
# {
# "showmore_analytics" : {"lk_pos":"bottom","event_name":"click – SERP – View More","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"bottom","lk_name":"showmore-results"}
# }
# </script>
# <div id="jsContactDialog"></div>
# <script id="analytics-resource-restricted" type="application/json">
# {
# "age_restricted_warning" : {"event_name":"impression - age restricted - warning","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"age_restricted_warning"},
# "age_restricted_close" : {"event_name":"click - age restricted - close","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"age_restricted_close"},
# "age_restricted_no" : {"event_name":"click - age restricted - no","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"age_restricted_no"},
# "age_restricted_yes" : {"event_name":"click - age restricted - yes","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"age_restricted_yes"}
# }
# </script>
# <script id="analytics-similar-businesses" type="application/json">
# {
# "impressionSimilarBusinesses" : {"pg_name":"impression - similar businesses - name search","event_name":"impression - similar businesses - name search","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"impression_similar_businesses"}
# }
# </script>
# <script id="mini_map_analytics" type="application/json">
# {
# "click_serp_mini_map_pin" : {"event_name":"click - SERP - Mini - Map - Pin","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"click_serp_mini_map_pin"},
# "click_serp_mini_map_pin_mobile" : {"event_name":"click - mobile map push pins","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O"},
# "click_view_down_serp_mini_map" : {"event_name":"click - slide listings down","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O"},
# "click_expend_map_mobile" : {"event_name":"click - bring map to front","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_name":"map_and_directions_exp"}
# }
# </script>
# <script id="autocompleteTemplate" type="text/x-handlebars-template">
# <span {{#if code}} class="disambiguation" {{else}} class="tt__category" {{/if}}>
# {{#if code}}
# {{alt}}
# {{else}}
# {{value}}
# {{/if}}
# </span>
# {{#if merchantDetail}}<span class="ypicon ypicon-business-unique business-unique"></span>{{/if}}
# </script>
# <script id="autocompleteTemplateForCurrentLocation" type="text/x-handlebars-template">
# <div id="currentLocationForTypeahead" class="suggested-location__current jsCurrentLocationForTypeahead">
# <ul class="suggested-location__list search-dropdown__list">
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem jsSuggestedLocationItemCurrent tt-suggestion tt-selectable" data-currentlocation-selected="1" data-label="Current Location" data-label-unresolvedlocation="Could not locate you" data-label-attemptlocate="Attempting to locate you">
# <span class="suggested-location__list__item--loading"></span>
# <span class="ypicon ypicon-curloc be-relative"></span>
# <span class="jsCurrentLocationItem">{{ currentLocation }}</span>
# </li>
# </ul>
# </div>
# </script>
# <script id="whereFieldTemplate" type="text/x-handlebars-template">
# {{#if currentLocation}}
# <div id="suggestedLocationDropdown" class="suggested-location search-dropdown jsSuggestedLocation">
# <div class="suggested-location__wrapper search-dropdown__wrapper">
# <div class="suggested-location__wrapper--inner search-dropdown__wrapper--inner">
# <div class="suggested-location__wrapper__inside search-dropdown__wrapper__inside">
# <div id="currentLocation" class="suggested-location__current">
# <ul class="suggested-location__list search-dropdown__list">
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem jsSuggestedLocationItemCurrent tt-suggestion tt-selectable" data-currentlocation-selected="1" data-label="Current Location" data-label-unresolvedlocation="Could not locate you" data-label-attemptlocate="Attempting to locate you">
# <span class="suggested-location__list__item--loading"></span>
# <span class="ypicon ypicon-curloc be-relative"></span>
# <span class="jsCurrentLocationItem">{{ currentLocation }}</span>
# </li>
# </ul>
# </div>
# <div id="previousLocation" class="suggested-location__previous jsPreviousLocation">
# <h2 class="suggested-location__title search-dropdown__title jsSuggestedPreviousLocationListLabel">
# <span class="search-dropdown__title--label suggested-location__title--label">
# {{#if previouslySearched}}
# Previous Locations
# {{else}}
# Previous Location
# {{/if}}
# </span>
# {{#if previouslySearched}}
# <span class="search-dropdown__title--button suggested-location__title--button jsClearSearchedLocation" role="button">Clear all</span>
# {{/if}}
# </h2>
# <div class="suggested-location__placeholder__animation">&nbsp;</div>
# <ul class="suggested-location__list search-dropdown__list jsSuggestedLocationList">
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem">{{ geoIpLocation }}</li>
# {{#if previouslySearched}}
# {{#each previouslySearched}}
#
# {{#ifCond ../geoIpLocation '!==' this }}
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem">{{ this }}</li>
# {{/ifCond}}
# {{/each}}
# {{/if}}
# </ul>
# <p class="suggested-location__message_success jsSuggestedLocationMsgSuccess">Your recent locations have been cleared</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# {{/if}}
# </script>
# <script class="jsWhatFieldTemplate" id="whatFieldTemplate" type="text/x-handlebars-template">
# {{#if previouslySearched}}
# <div id="previousSearchesDropdown" class="previous-searches search-dropdown jsPreviousSearch">
# <div class="previous-searches__wrapper search-dropdown__wrapper">
# <div class="previous-searches__wrapper--inner search-dropdown__wrapper--inner jsPreviousSearchInner">
# <div class="previous-searches__wrapper__inside search-dropdown__wrapper__inside">
# <h2 class="previous-searches__title search-dropdown__title">Previous search(es)<span class="search-dropdown__title--button suggested-location__title--button jsClearSearchedWhat" role="button">Clear all</span>
# </h2>
# <ul class="previous-searches__list search-dropdown__list jsPreviousSearchList">
# {{#each previouslySearched}}
# <li class="previous-searches__list__item search-dropdown__list__item jsPreviousSearchItem">{{ this }}</li>
# {{/each}}
# </ul>
# </div>
# </div>
# </div>
# </div>
# {{/if}}
# </script>
# <script id="feature-where-smart-autocomplete" type="application/json">
# {
# "isWhereSuggestedLocation" : true,
# "deleteCookiesURL" : "/ajax/utilities/eraseRecentWhereSearches",
# "messages": {
# "locationLabel": "Current Location",
# "locationNearYouLabel": "Current location near you in",
# "currentLocationLabelForMap" : "My location"
# }
# }
# </script>
# <script class="jsProxyYidConfig" id="proxy-yid-config" type="application/json">
# {
# "otherSideBaseUrl" : "https://www.pagesjaunes.ca/proxy",
# "otherSideBaseUrlPasswordless" : "https://www.pagesjaunes.ca/proxyPasswordLess"
# }
# </script>
# <script class="jsSuggestedLocationsConfig" type="application/json">
# {
# "suggestedLocationLabel" : "Suggested locations"
# }
# </script>
# <script class="jsPageConfigurationResource" id="page-configuration-resource" type="application/json">
# {
# "mapSearch": false,
# "isCobrand": false,
# "cookieDomain": ".yellowpages.ca",
# "analytics": {
# "mapLocation": {"lk_pos":"in_listing","event_name":"click - View My Location","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"left_2","lk_name":"locate-me"},
# "zoomedIn": {"lk_pos":"mapanddirections","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"left_1","lk_name":"zoom-in"},
# "zoomedOut": {"lk_pos":"mapanddirections","lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_area":"left_1","lk_name":"zoom-out"}
# }
# }
# </script>
# <script id="search-action-resource" type="application/json">
# {
# "currentLanguage": "en",
# "currentLocation": "Toronto, ON",
# "defaultSearch": "/search/si/1/{{what}}/{{where}}",
# "personSearch": {
# "en": "http://www.canada411.ca/search/si/1/{{what}}/{{where}}/",
# "fr": "http://www.fr.canada411.ca/search/si/1/{{what}}/{{where}}/"
# },
# "geolocationMaxAgeConfiguration": "600000",
# "isExternalReferrer": "false",
# "maskedLocationLabel": "Near me",
# "maskedLocationLabelGetDirections": "My location"
# }
# </script>
# <script class="jsIsSafariOrIE" type="application/json">
# {
# "safariOrIE" : "false"
# }
# </script>
# <script data-analytics-resource="true" id="autocomplete-analytics-resource" type="application/json">
# {"autocomplete_what":{"context":{},"binding":"autocomplete_what","data-analytics":{"lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_what_user":"Restaurants","lk_pos":"in_autocomplete","lk_what_ac_idx":"-1","lk_what_ac_txt":"","lk_area":"in_autocomplete","lk_name":"busnameautocomplete-serp"}},"autocomplete_where":{"context":{},"binding":"autocomplete_where","data-analytics":{"lk_se_id":"858e2dbe-4a37-4bfb-8893-d34ea47e17a0_UmVzdGF1cmFudHM_TG9uZG9uIE9O","lk_where_ac_txt":"","lk_where_user":"London ON","lk_where_ac_idx":"-1"}}}</script>
# <!-- comScore Identifier: comscorekw=RESTAURANTS%20%26%20BARS -->
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/tags.js" type="text/javascript"></script><script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/gpt.js" type="text/javascript"></script><script id="jsGenConfig" type="application/json">
# {
# "cookieDomain" : ".yellowpages.ca"
# }
# </script>
# <script async="" src="//cdn.districtm.ca/merge/merge.v4.2.103991.js"></script>
# <script type="text/javascript">
# if(aJsFiles.length > 0) {
# if (window.fetch && typeof window.fetch !== 'undefined') {
# fetchInject(aJsFiles.slice(1, aJsFiles.length),fetchInject([aJsFiles[0]]));
# } else {
# $YPCA.loopDeferScript(aJsFiles);
# }
# }
# </script>
# <!-- Global site tag (gtag.js) - Google Ads: AW-794878240 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-794878240"></script>
# <!-- Global site tag (gtag.js) - Google Analytics:  -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-126563938-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
#
# function gtag() {
# dataLayer.push(arguments);
# }
#
# gtag('js', new Date());
# // Sending the pageview to multiple Google Analytics properties by specifying a config for each property
# gtag('config', 'AW-794878240');
# gtag('config', 'UA-126563938-1');
# </script>
# <script>
# jQuery(document).ready(function ($) {
# jQuery('body').on('mousedown touchstart', '[data-analytics]', function (e) {
# var targetElement = jQuery(e.currentTarget),
# tagName = targetElement.prop("tagName");
# if (tagName !== "OPTION" && tagName !== "SELECT") {
# var event = targetElement.attr('data-analytics-event');
# if (!YPCA.Utils.isDefined(event) || event === 'mousedown') {
# var analyticsJson = YPCA.Utils.parseJSONGracefully(targetElement.attr('data-analytics'));
# if (YPCA.Utils.isDefined(analyticsJson) && analyticsJson.hasOwnProperty('lk_name')) {
# gtag_report_conversion(analyticsJson.lk_name);
# }
# }
# }
# });
# });
# </script>
# <script>
# function detectMobile() {
# return false;
# }
#
# function sendTo(lkName) {
# var sendTo;
# switch (lkName) {
# case "email-confirm":
# if (detectMobile()) {
# sendTo = "-cMnCImb2I";
# } else {
# sendTo = "4o8cCPGR2I";
# }
# break;
# case "message-confirm":
# if (detectMobile()) {
# sendTo = "KYt_CL-b2I";
# } else {
# sendTo = "JJGoCMWEyY";
# }
# break;
# case "orderonline-confirm":
# if (detectMobile()) {
# sendTo = "Lmu7CPGa2I";
# } else {
# sendTo = "y67RCKKZ2I";
# }
# break;
# case "reserve-confirm":
# if (detectMobile()) {
# sendTo = "KQqCCKK84Y";
# } else {
# sendTo = "ZmjWCLGZ2I";
# }
# break;
# case "reserve-step1-failed":
# if (detectMobile()) {
# sendTo = "LrMPCIid2I";
# } else {
# sendTo = "JPu6CIeZ2I";
# }
# break;
# case "reserve-step1failed":
# sendTo = "DVJtCIiGyY";
# break;
# case "revealphonenumber":
# sendTo = "LD5-COyY2I";
# break;
# case "directions-step1":
# sendTo = "2YpFCNq44Y";
# break;
# case "directions-confirm":
# sendTo = "FO8bCMS64Y";
# break;
# case "mobilecall":
# sendTo = "sYlACOP-yI";
# break;
# default:
# return null;
# }
# return "AW-794878240/" + sendTo + "YBEKDCg_sC";
# }
#
# function gtag_report_conversion(lkName) {
# var account = sendTo(lkName);
# if (account) {
# var jsfunction = function () {
# lkName;
# }
# gtag('event', 'conversion', {
# 'send_to': account,
# 'event_callback': jsfunction
# });
# }
#
# return false;
# }
#
# </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","licenseKey":"d901b4dcbe","agent":"","beacon":"bam.nr-data.net","applicationTime":481,"applicationID":"498805584","transactionName":"YgQEYUFVV0IDB0wNDltONUVBXVdWIQtWEBNaDQpQQRtKVAMWWwxOThISTENRA2oDSUI5SkhOHUVUDmJtBjkTGU5OFg5UR0kWShUMXRYED09MSBMcfnQ2TQ==","queueTime":0}</script></body>
# </html>

# %%
results = soup.find_all('div', {'class':"listing"})
len(results)
# Out:
# 35

# %%
#name
results[0].img['alt']
# Out:
# 'Jewel Of India Restaurant Inc - Restaurants'

# %%
#address
results[0].find('span', {'class':"jsMapBubbleAddress"}).get_text()
# Out:
# '390 Richmond St'

# %%
#rating
results[0].find('a', {'class': "listing__ratings__count listing__link"}).get_text().strip()
# Out:
# '(17)'

# %%
#href
href = results[0].find('a', {'class': "listing__name--link listing__link jsListingName"})['href']
href
# Out:
# '/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&where=London+ON&useContext=true'

# %%
#url
url = 'https://www.yellowpages.ca'

# %% [markdown]
# ### Page about current restaurant

# %%
#link
link = urljoin(url, href)
link
# Out:
# 'https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&where=London+ON&useContext=true'

# %%
#response
response_2 = requests.get(link)

# %%
print(response_2)
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(response_2.content, 'html.parser')
soup2
# Out:
# <!DOCTYPE HTML>
#
# <html class="no-js critical-off C00" lang="en-CA" xml:lang="en-CA" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"498849646",accountID:"824834",trustKey:"45968",xpid:"XAQDWVVXGwcJXFlSAgQPUg==",licenseKey:"d901b4dcbe",applicationID:"498805584"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b=" ...
# .side-menu{position:fixed;top:0;overflow:auto;width:280px;height:100%;z-index:202}.side-menu.side-menu--left{left:-280px;transition:left .5s ease}.side-menu--left--open .side-menu.side-menu--left.side-menu--left{left:0;box-shadow:1px 2px 4px rgba(0,0,0,.2)}.side-menu.side-menu--right{right:-280px;transition:right .5s ease}.side-menu--right--open .side-menu.side-menu--right.side-menu--right{right:0;z-index:1001}.side-menu.side-menu--mobile{right:-280px;transition:right .5s ease}.side-menu--mobile--open .side-menu.side-menu--mobile.side-menu--mobile{right:15px;z-index:1001}.overlay__container{display:none}.hidden{display:none!important}.upcase{text-transform:uppercase}.hide-text{text-indent:100%;white-space:nowrap;overflow:hidden;position:absolute}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.visuallyhidden{position:absolute;overflow:hidden;clip:rect(0 0 0 0);height:1px;width:1px;margin:-1px;padding:0;border:0}.quote__after{text-decoration:none}.quote__after:after{content:' \00BB '}.quote__before{text-decoration:none}.quote__before:before{content:'\00AB '}.v-hidden{visibility:hidden}body,html{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline}html{line-height:1}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font:inherit;font-size:100%;vertical-align:baseline}ol,ul{list-style:none}table{border-collapse:collapse;border-spacing:0}caption,td,th{text-align:left;vertical-align:middle}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}a img{border:none}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section,summary{display:block}body,html{width:100%;height:100%;background-color:#f3f3f3}body{font-family:"YP Local",sans-serif;font-size:90%;color:#333;font-weight:100;line-height:140%;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}*,:after,:before{box-sizing:border-box}a{text-decoration:underline;color:#333}a:hover{text-decoration:none}.italic,em,i{font-style:italic}b,strong{font-weight:300}input{font-weight:100}button,input{font-family:"YP Local",sans-serif}::selection{color:#333;background-color:#ffcd00}input[type=text]::-ms-clear{display:none}figure{margin:0}form{margin:0}button{border:0;margin:0;padding:0;cursor:pointer}address{font-style:normal}ul{padding:0;margin:0;list-style:none}.page__wrapper{display:-ms-flexbox;display:flex;-ms-flex-align:stretch;align-items:stretch;-ms-flex-negative:0;flex-shrink:0;-ms-flex-direction:column;flex-direction:column;margin:0;padding:0;height:100%}#cobrand .page__wrapper{height:calc(100vh - 88px)}.page__footer,.page__header{-ms-flex:0 0 auto;flex:0 0 auto}.page-CONTACT_US .page__header,.page-MERCHANT_DIRECTIONS .page__header{margin-bottom:10px}.ypg_mediative_smart_tips{margin-bottom:20px;display:-ms-flexbox;display:flex;-ms-flex-pack:center;justify-content:center}.ypg_mediative_smart_tips>div{overflow:hidden}.page__container{-ms-flex:1 0 auto;flex:1 0 auto}@media (min-width:851px){.page__container:not(.page__container--mapview) .page__sidebar{width:296px}}@media (min-width:600px){.page__container .page__sidebar--left{margin-right:20px}}@media (min-width:851px){.page__container .page__sidebar--right{margin-left:50px;padding-top:72px}}.page__container .page__content-wrap{margin-bottom:30px;background-color:#fff;border-radius:2px;box-shadow:0 2px 2px -1px rgba(0,0,0,.2);line-height:130%}.page__container .page__content-wrap:after,.page__container .page__content-wrap:before{content:" ";display:table}.page__container .page__content-wrap:after{clear:bo ...
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowJQuery.js" type="text/javascript"></script><!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M3TSKZ2');</script>
# <!-- End Google Tag Manager -->
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/baseYellow_core.js" type="text/javascript"></script><meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">(function(){var c = document.getElementsByTagName('html')[0];c.className = c.className.replace(/no-js/, 'js');})()</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="none" name="msapplication-config">
# <meta content="initial-scale=1.0, maximum-scale=1.0, width=device-width" name="viewport"/>
# <meta content="#FFCD00" name="theme-color"/>
# <meta content="#FFCD00" name="msapplication-navbutton-color"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="Origin" name="referrer"/>
# <meta content="en-CA" name="DC.Language">
# <title>Jewel Of India Restaurant Inc - Menu, Hours &amp; Prices - 390 Richmond St, London, ON</title>
# <meta content="Jewel Of India Restaurant Inc - London - phone number, website, address &amp; opening hours - ON - Indian Restaurants, Restaurants, Rotisseries &amp; Chicken Restaurants." name="description">
# <meta content="com.ypg.yellowpages://mid?mid=856752&amp;what=Restaurants&amp;where=London+ON&amp;useContext=true" property="al:ios:url">
# <meta content="322964940" property="al:ios:app_store_id">
# <meta content="YP Yellow Pages Canada" property="al:ios:app_name"/>
# <meta content="com.ypg.find://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON&amp;useContext=true" property="al:android:url"/>
# <meta content="YP Yellow Pages Canada" property="al:android:app_name"/>
# <meta content="com.ypg.find" property="al:android:package"/>
# <meta content="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON&amp;useContext=true" property="al:web:url"/>
# <link href="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON&amp;useContext=true" hreflang="en-ca" rel="alternate"/>
# <link href="https://www.pagesjaunes.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON&amp;useContext=true" hreflang="fr-ca" rel="alternate"/>
# <link href="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html" rel="canonical"/>
# <link href="android-app://com.ypg.find/http/www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html" rel="alternate"/>
# <meta content="https://ssmscdn.yp.ca/banner/merchant/2/856752/en/jewel-of-india-restaurant-inc.jpg" property="og:image"/>
# <meta content="1004441262966232" property="fb:app_id"/>
# <meta content="restaurant" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="YellowPages.ca" property="og:site_name"/>
# <meta content="Jewel Of India Restaurant Inc - Indian Restaurants - London" property="og:title"/>
# <meta content="630" property="og:image:height"/>
# <meta content="716482783,504830416,615841352" property="fb:admins"/>
# <meta content="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html" property="og:url"/>
# <meta content="Take your taste buds on a trip around the world with Jewel of India Restaurant Inc. Located in London, we serve dishes such as biryani, dupiaza, dansak, tandoori, vindaloo and much..." property="og:description"/>
# <meta content="Jewel Of India Restaurant Inc - Indian Restaurants - London" name="twitter:title"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@ypdine" name="twitter:site"/>
# <meta content="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html" name="twitter:url"/>
# <meta content="Take your taste buds on a trip around the world with Jewel of India Restaurant Inc. Located in London, we serve dishes such as biryani, dupiaza, dansak, tandoori, vindaloo and much..." name="twitter:description"/>
# <meta content="https://ssmscdn.yp.ca/banner/merchant/2/856752/en/jewel-of-india-restaurant-inc.jpg" name="twitter:image:src"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.eot?e1cvpc" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.ttf?e1cvpc" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.woff?e1cvpc" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/payment-fonts/ypca-icons.svg?e1cvpc#ypca-icons" rel="preload"/>
# <link as="style" href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowMapsModule_osm.css" rel="preload"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//static.yellowpages.ca" rel="dns-prefetch"/>
# <link href="//cdn.tile.yellowpages.ca" rel="dns-prefetch"/>
# <link href="//ssvs.yp.ca" rel="dns-prefetch"/>
# <link href="//cdn.media.yp.ca" rel="dns-prefetch"/>
# <link href="//cdn.ci.yp.ca" rel="dns-prefetch"/>
# <link href="//ssmscdn.yp.ca" rel="dns-prefetch"/>
# <link href="//static.cms.yp.ca" rel="dns-prefetch"/>
# <link href="//cdn.cb.yp.ca" rel="dns-prefetch"/>
# <link href="//api.amplitude.com" rel="dns-prefetch"/>
# <link href="//static.criteo.net" rel="dns-prefetch"/>
# <link href="//bam.nr-data.net" rel="dns-prefetch"/>
# <link href="//gum.criteo.com" rel="dns-prefetch"/>
# <link href="//984-yin-134.mktoresp.com" rel="dns-prefetch"/>
# <link href="//logger.yp.ca" rel="dns-prefetch"/>
# <link href="//as-sec.casalemedia.com" rel="dns-prefetch"/>
# <link href="//sb.scorecardresearch.com" rel="dns-prefetch"/>
# <link href="//secure.adnxs.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//adservice.google.ca" rel="dns-prefetch"/>
# <link href="//adservice.google.com" rel="dns-prefetch"/>
# <link href="//cdn.krxd.net" rel="dns-prefetch"/>
# <link href="//cdn.districtm.io" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//www.googleadservices.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/galleryImages.css" rel="stylesheet" type="text/css"><link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/merchantMedia.css" rel="stylesheet" type="text/css"><link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/merchantMenu.css" rel="stylesheet" type="text/css"><link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowReviews.css" rel="stylesheet" type="text/css"><script type="text/javascript">function logRequest(){try{var t;if(window.XMLHttpRequest)t=new XMLHttpRequest;else if(window.ActiveXObject)try{t=new ActiveXObject("Msxml2.XMLHTTP")}catch(e){try{t=new ActiveXObject("Microsoft.XMLHTTP")}catch(e){}}t&&(t.open("GET","/ajax/utilities/frame?referrer="+document.referrer,!0),t.send())}catch(e){}};function checkIfWhiteListed(){var obj=[".*urbanizer.yp.ca.*",".*urbanizer.ca.*",".*urbanizer.qa.yp.ca.*",".*urbanizer.com.*"];var testurl="";if(this.top.location!==this.location){testurl=document.referrer}else{testurl=this.top.location}for(var i=0;i<obj.length;i++){if(new RegExp(obj[i]).test(testurl)){return true}}return false};this.top.location!==this.location&&!checkIfWhiteListed()&&(logRequest(),this.top.location=this.location);</script>
# <link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/criticalMerchantDesktop.css" rel="stylesheet" type="text/css"><style>
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Book.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Book.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Book.ttf') format('truetype');
# font-weight: 100;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Medium.ttf') format('truetype');
# font-weight: 300;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-Bold.ttf') format('truetype');
# font-weight: 600;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Local';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yplocal/YPLocalWeb-BookItalic.ttf') format('truetype');
# font-style: italic;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'YP Hand';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/yphand/YPHandWeb-Regular.ttf') format('truetype');
# font-weight: normal;
# font-style: normal;
# font-display: swap;
# }
#
# @font-face {
# font-family: 'yp-icons';
# src: url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.woff2') format('woff2'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.woff') format('woff'),
# url('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/fonts/ypicons/ypca-icons.ttf') format('truetype');
# font-weight: normal;
# font-style: normal;
# font-display: swap;
# }
# </style>
# <!-- Is it Defer? no -->
# <link href="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowMerchant.css" rel="stylesheet" type="text/css"><meta content="www.yellowpages.ca;6.69.0.0 (rev 20220823.0703);ProdYPAWS01" name="info">
# <script type="text/javascript">
# var aJsFiles = [];
# </script>
# </meta></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body class="ypg ypg_merchant lang-en deviceDesktop jsDeviceDesktop page-MERCHANT context-dine nearMeOn merchantBodyClass notLoggedIn">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3TSKZ2" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="overlay__container jsOverlayContainer"></div>
# <div class="page__wrapper ypgBody" id="ypgBody">
# <script class="jsGenericRedirectConfig" type="application/json">
# {
# "redirect": false,
# "url": ""
# }
# </script>
# <div class="page__header jsHeader" id="ypg_Header">
# <header class="ypg-header jsHeaderWrapper">
# <div class="ypg-header__root">
# <div class="ypg-header__holder jsHeaderHolder">
# <div class="ypg-header__wrapper yp-header__wrapper__home">
# <div class="action-bar">
# <div class="action-bar__left ypg-header-left">
# <div class="ypg-logo">
# <a data-analytics='{"lk_pos":"header","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_area":"header","lk_name":"yplogo"}' data-qa="QAypLogoLhs" href="/" id="QAypLogoLhs" title="Yellowpages.ca Canadian Business Directory - Meet the New Neighbourhood"><img alt="Visit YP.ca to search for businesses in Canada" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/images/verticals/yellowpages/logo-en.svg"/></a>
# </div>
# </div>
# <div class="action-bar__form search-form mobileSearch__form home_header_search_form jsUpdateBptnUser">
# <div class="action-bar__close"><button class="jsCloseSearch"><span class="ypicon ypicon-newx"></span></button></div>
# <form accept-charset="UTF-8" class="inputForm ypg-searchform jsSearchForm" data-action="/search/si/1/{{what}}/{{where}}" data-analytics='{"lk_pos":"top","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_area":"top","lk_name":"find"}' data-analytics-event="submit" data-search-type="business" id="inputForm" method="get" name="findform">
# <input id="latitude" name="latitude" type="hidden"/>
# <input id="longitude" name="longitude" type="hidden"/>
# <input id="mobiCode" name="mobiCode" type="hidden"/>
# <input id="sflag" name="sflag" type="hidden"/>
# <div class="inputFormWhat inputWrap search-form__item jsToolTipSpecifiDish jsSearchWhatWrapper">
# <div class="search-field-outer jsSearchWhatInner" id="searchwhat">
# <label class="sr-only" for="whatwho">Please enter what you're searching for</label>
# <input autocomplete="off" class="search-field typeahead height40" data-default="What? (E.g. cuisine, meal)" id="whatwho" maxlength="100" name="what" placeholder="What? (E.g. cuisine, meal)" required="required" size="100" type="text" value=""/>
# </div>
# </div>
# <div class="searchFormMobileDisplay">
# <div class="inputFormWhere inputWrap search-form__item jsSearchWhereWrapper">
# <div class="search-field-outer jsToolTipNearMe search-field__previouslocation" id="searchwhere">
# <label class="sr-only" for="where">Please enter your search location</label>
# <input autocomplete="off" class="search-field typeahead height40" data-default="Where? (E.g. Toronto)" data-geoip-location="Toronto, ON" data-location="Toronto, ON" id="where" maxlength="250" name="where" placeholder="Where? (E.g. Toronto)" required="required" size="250" type="text" value="Toronto, ON"/>
# <span class="ypicon ypicon-curloc search-field--icon jsIconCurloc hidden"></span>
# <input autocomplete="off" class="search-field search-field--mask hidden jsWhere height40" data-default="Where? (E.g. Toronto)" data-geoip-location="Toronto, ON" data-location="Toronto, ON" maxlength="250" placeholder="Where? (E.g. Toronto)" size="100" type="text" value="Near me"/>
# </div>
# </div>
# <div class="actionWrap search-form__item">
# <div class="inputFormFind">
# <button class="search-form__button jsBtnSearchForm height40" name="search_button" title="Find." type="submit">
# <span class="search__icon"></span>
# <span class="visuallyhidden">Search</span>
# </button>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="linksHeader">
# <ul class="ypg-connect ypg-header-right_menu header-links ypg-connect--login jsConnectInfos">
# <li><a class="jsConnectButton" data-modal-url="/ajax/user/signin" data-qa="QAsignInLink" data-target="#jsModalContainer" data-toggle="ajax-modal">Log in</a></li>
# <li class="upcase">
# <a class="jsOtherLanguageUrl" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"header","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"header","lk_name":"toggle_en"}' href="https://www.pagesjaunes.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON&amp;useContext=true&amp;theme=dine" title="Visit Yellow Pages in French">
# fr<span class="visuallyhidden">Passer en français / Switch to French language</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="ypalert ypalert--success authenticated--user--alert jsAlertBox jsAlertBoxUserConfirmed hidden">
# <button aria-hidden="true" class="close jsCloseAlert" type="button">×</button>
# Your account is now active!</div>
# <div class="ypg-cover hide-print">
# <span class="cover-image jsBanner"></span>
# </div>
# </div>
# <link href="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?ReviewsPageNumber=2" rel="next">
# <div class="merchant__info__sticky">
# <div class="merchant__info-content">
# <div class="merchant__name">
# <span class="merchantInfo-title merchant__title">
# <span class="merchant-title__name jsShowCTA" itemprop="name">Jewel Of India Restaurant Inc</span> </span>
# <div class="merchant__overall_rating_container merchant__details__rating__content jsStarsContainer jsBusinessDetailsRating">
# <span class="active ypStars__item"></span>
# <div class="merchant__overall_rating"><span class="merchant__rating" data-toggle="tooltip" title="Based on 17 YP ratings">3.8</span>/5</div>
# </div>
# </div>
# <div class="middle_section">
# <div class="merchant__mlr">
# <div class="mlr__merchant__root item4">
# <ul class="mlr mlr--merchant">
# <!-- here too -->
# <li class="mlr__item mlr__item--more mlr__item--phone">
# <a class="mlr__item__cta jsMlrMenu" data-analytics-placeholder='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"tophidden","event_name":"click - Call - Reveal Phone Number","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"revealphonenumber","page_section":"Merchant Page - Top Sticky Bar"}' href="#">
# <div class="messageIcon">
# <span class="ypicon ypicon-phone mlr__icon"></span><span class="messageText">Phone Number</span></div>
# </a>
# <ul class="mlr__submenu jsMlrSubMenu">
# <li class="mlr__submenu__item"><span class="mlr__sub-text" itemprop="telephone" tabindex="0">226-781-1101</span><span class="mlr__label">Primary</span></li></ul>
# </li>
# <li class="mlr__item mlr__item--message hide-print">
# <a class="ypModal mlr__item__cta merchantMessage jsMerchantMessage" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Message","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_2","lk_name":"message-step1","page_section":"Merchant Page - Top Sticky Bar"}' data-mid="856752" data-modal-url="https://www.yellowpages.ca/ajax/messaging/merchantMessageDialog?id=856752&amp;name=Jewel+Of+India+Restaurant+Inc&amp;address=390+Richmond+St%2C+London%2C+ON+N6A+3C7&amp;requestSource&amp;lang=en=merchant" data-target="#jsModalContainer" data-toggle="ajax-modal" href="javascript:void(0);">
# <div class="messageIcon"><span class="ypicon ypicon-message-bubble mlr__icon"></span><span class="newMessage">Message</span></div>
# </a>
# </li>
# <li class="mlr__item mlr__item--direction hide-print">
# <a class="mlr__item__cta" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"calltoactionmenu","event_name":"click - Directions - Intent","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"tophidden","lk_name":"directions-step1","page_section":"Merchant Page - Top Sticky Bar"}' href="/merchant/directions/856752/?what=Restaurants&amp;where=London+ON" rel="nofollow" title="Get directions">
# <div class="messageIcon"><span class="ypicon ypicon-getDirection mlr__icon"></span><span class="newMessage">Directions</span></div>
# </a>
# </li>
# <li class="mlr__item mlr__item--website mlr__item--more">
# <a class="mlr__item__cta jsMlrMenu hide-print" data-analytics-placeholder='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Website","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"website-viewlist","page_section":"Merchant Page - Top Sticky Bar"}' href="#" title="Visit Jewel Of India Restaurant Inc's website">
# <div class="messageIcon">
# <span class="ypicon ypicon-web mlr__icon"></span>
# <span class="ctatext"><span class="newMessage">Websites</span></span>
# </div>
# </a>
# <ul class="mlr__submenu jsMlrSubMenu">
# <li class="mlr__submenu__item mlr__submenu__itemprint">
# <span class="mlr__sub-text">www.jewelofindiarestaurant.ca</span>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemnotprint">
# <a class="" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Website","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"website"}' href="/gourl/839ca1a0960e1fd33ac08561813b1fcf6d8bce39?redirect=http%3A%2F%2Fwww.jewelofindiarestaurant.ca%2F" rel="nofollow" target="_blank">
# <span class="mlr__sub-text">http://www.jewelofindiarestaurant.ca</span>
# <span class="ypicon ypicon-wss"></span>
# </a>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemprint">
# <span class="mlr__sub-text">jewelofindiarestaurant.ca</span>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemnotprint">
# <a class="" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Website","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"website"}' href="/gourl/351c9f5431f41320c80ce57956e657393f36c9c6?redirect=http%3A%2F%2Fjewelofindiarestaurant.ca%2F" rel="nofollow" target="_blank">
# <span class="mlr__sub-text">http://jewelofindiarestaurant.ca</span>
# <span class="ypicon ypicon-wss"></span>
# </a>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemnotprint">
# <a class="" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - social - facebook","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"facebookmerchant"}' href="/gourl/59016b3b36750e318f03f954febb1346f7ba1cd5?redirect=https%3A%2F%2Fwww.facebook.com%2Fpages%2FJewel-of-India-Restaurant-Inc%2F134577806568775" rel="nofollow" target="_blank" title="Facebook">
# <span class="mlr__sub-text">https://www.facebook.com/pages/Jewel-of-India-Restaurant-Inc/134577806568775</span>
# <span class="ypicon ypicon-facebook"></span>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="merchant__item merchant__open">
# <div class="merchant__status tooltip__toggle see-hours" data-placement="top" data-toggle="tooltip">
# <a class="merchant__status-text merchant__status__closed__now-text goToByScroll" data-analytics='{"event_name":"click - Opening Hours","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"opening_hours"}' href="/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON#openHourScroll">Opening at 11:30 am</a>
# </div><span class="see-hours"> <a class="goToByScroll hours-ie" href="#openHourScroll">, See all hours</a></span>
# </div>
# </div>
# </div>
# </div>
# <div class="page__container" itemscope="" itemtype="http://schema.org/Restaurant">
# <meta content="https://cdn.ci.yp.ca/t/1546/38/15463879aa_t.gif" itemprop="image"/>
# <meta content="https://www.yellowpages.ca/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html" itemprop="url"/>
# <div class="merchant__header--root">
# <div class="merchant__info hasLogo">
# <div class="merchant__logo--root">
# <div class="merchant__logo">
# <a class="merchant-logo-link" href="/gourl/839ca1a0960e1fd33ac08561813b1fcf6d8bce39?redirect=http%3A%2F%2Fwww.jewelofindiarestaurant.ca%2F" rel="noopener" target="_blank">
# <img alt="Jewel Of India Restaurant Inc - Logo" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_type":"website","lk_pos":"in_mp","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"logo-website"}' itemprop="logo" src="https://cdn.ci.yp.ca/t/1546/38/15463879aa_t.gif">
# </img></a>
# </div>
# </div>
# <!-- Merchant info -->
# <div class="merchant__info--root">
# <div class="merchant__info-content">
# <div class="merchant__name">
# <h1 class="merchantInfo-title merchant__title"><span class="merchantNamejsShowCTA" itemprop="name">Jewel Of India Restaurant Inc</span> </h1>
# <div class="merchant__item merchant__address merchant__address__mobile" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress" tabindex="0">
# <span itemprop="streetAddress">390 Richmond St</span>, <span itemprop="addressLocality">London</span>, <span itemprop="addressRegion">ON</span> <span itemprop="postalCode">N6A 3C7</span><span class="getDirectionHeader">
# <a class="hide-print" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Directions - Intent","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1b","lk_name":"directions-step1","page_section":"Merchant Page - Get Directions - Address Link"}' href="/merchant/directions/856752/?what=Restaurants&amp;where=London+ON" rel="nofollow" title="Get directions">Get directions »</a>
# </span>
# </div>
# </div>
# <div class="middle_section">
# <div class="merchant__mlr">
# <div class="mlr__merchant__root item4">
# <ul class="mlr mlr--merchant">
# <!-- here too -->
# <li class="mlr__item mlr__item--more mlr__item--phone">
# <a class="mlr__item__cta jsMlrMenu" data-analytics-placeholder='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Call - Reveal Phone Number","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"revealphonenumber","page_section":"Merchant Page - Top Bar"}' href="#">
# <div class="messageIcon">
# <span class="ypicon ypicon-phone mlr__icon"></span><span class="messageText">Phone Number</span></div>
# </a>
# <ul class="mlr__submenu jsMlrSubMenu">
# <li class="mlr__submenu__item"><span class="mlr__sub-text" itemprop="telephone" tabindex="0">226-781-1101</span><span class="mlr__label">Primary</span></li></ul>
# </li>
# <li class="mlr__item mlr__item--message hide-print">
# <a class="ypModal mlr__item__cta merchantMessage jsMerchantMessage" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Message","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_2","lk_name":"message-step1","page_section":"Merchant Page - Top Bar"}' data-mid="856752" data-modal-url="https://www.yellowpages.ca/ajax/messaging/merchantMessageDialog?id=856752&amp;name=Jewel+Of+India+Restaurant+Inc&amp;address=390+Richmond+St%2C+London%2C+ON+N6A+3C7&amp;requestSource&amp;lang=en=merchant" data-target="#jsModalContainer" data-toggle="ajax-modal" href="javascript:void(0);">
# <div class="messageIcon"><span class="ypicon ypicon-message-bubble mlr__icon"></span><span class="newMessage">Message</span></div>
# </a>
# </li>
# <li class="mlr__item mlr__item--direction hide-print">
# <a class="mlr__item__cta" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Directions - Intent","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"directions-step1","page_section":"Merchant Page - Top Bar"}' href="/merchant/directions/856752/?what=Restaurants&amp;where=London+ON" rel="nofollow" title="Get directions">
# <div class="messageIcon"><span class="ypicon ypicon-getDirection mlr__icon"></span><span class="newMessage">Directions</span></div>
# </a>
# </li>
# <li class="mlr__item mlr__item--website mlr__item--more">
# <a class="mlr__item__cta jsMlrMenu hide-print" data-analytics-placeholder='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Website","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"website-viewlist","page_section":"Merchant Page - Top Bar"}' href="#" title="Visit Jewel Of India Restaurant Inc's website">
# <div class="messageIcon">
# <span class="ypicon ypicon-web mlr__icon"></span>
# <span class="ctatext"><span class="newMessage">Websites</span></span>
# </div>
# </a>
# <ul class="mlr__submenu jsMlrSubMenu">
# <li class="mlr__submenu__item mlr__submenu__itemprint">
# <span class="mlr__sub-text">www.jewelofindiarestaurant.ca</span>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemnotprint">
# <a class="" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Website","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"website"}' href="/gourl/839ca1a0960e1fd33ac08561813b1fcf6d8bce39?redirect=http%3A%2F%2Fwww.jewelofindiarestaurant.ca%2F" rel="nofollow" target="_blank">
# <span class="mlr__sub-text">http://www.jewelofindiarestaurant.ca</span>
# <span class="ypicon ypicon-wss"></span>
# </a>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemprint">
# <span class="mlr__sub-text">jewelofindiarestaurant.ca</span>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemnotprint">
# <a class="" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Website","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"website"}' href="/gourl/351c9f5431f41320c80ce57956e657393f36c9c6?redirect=http%3A%2F%2Fjewelofindiarestaurant.ca%2F" rel="nofollow" target="_blank">
# <span class="mlr__sub-text">http://jewelofindiarestaurant.ca</span>
# <span class="ypicon ypicon-wss"></span>
# </a>
# </li>
# <li class="mlr__submenu__item mlr__submenu__itemnotprint">
# <a class="" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - social - facebook","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"facebookmerchant"}' href="/gourl/59016b3b36750e318f03f954febb1346f7ba1cd5?redirect=https%3A%2F%2Fwww.facebook.com%2Fpages%2FJewel-of-India-Restaurant-Inc%2F134577806568775" rel="nofollow" target="_blank" title="Facebook">
# <span class="mlr__sub-text">https://www.facebook.com/pages/Jewel-of-India-Restaurant-Inc/134577806568775</span>
# <span class="ypicon ypicon-facebook"></span>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="merchant__item merchant__open">
# <div class="merchant__status tooltip__toggle see-hours" data-placement="top" data-toggle="tooltip">
# <a class="merchant__status-text merchant__status__closed__now-text goToByScroll" data-analytics='{"event_name":"click - Opening Hours","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"opening_hours"}' href="/bus/Ontario/London/Jewel-Of-India-Restaurant-Inc/856752.html?what=Restaurants&amp;where=London+ON#openHourScroll">Opening at 11:30 am</a>
# </div><span class="see-hours"> <a class="goToByScroll" href="#openHourScroll">, See all hours</a></span>
# </div>
# </div>
# </div>
# <div>
# <div class="merchant__overall_rating_container merchant__details__rating__content jsStarsContainer jsBusinessDetailsRating">
# <a class="ypStars-wrapper jsHeaderChart goToByScroll" data-analytics='{"event_name":"click - Read Reviews","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"star-review"}' href="#ypgReviewsHeader">
# <span aria-label="rating 4" class="ypStars jsReviewsChart" data-rating="rating4" tabindex="0">
# <span class="star1 ypStars__item"></span>
# <span class="star2 ypStars__item"></span>
# <span class="star3 ypStars__item"></span>
# <span class="star4 ypStars__item"></span>
# <span class="star5 ypStars__item"></span>
# </span>
# </a>
# <div class="merchant__item viewComment">
# <a class="goToByScroll jsScrollToYpReview" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Read Reviews","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1b","lk_name":"read_yp_reviews"}' href="#ypgReviewsHeader">Read review(s) »</a>
# </div>
# </div>
# </div>
# </div>
# <div class="jsStaticPrintMapContainer staticMapContainer staticMapContainer--print hidden" data-url="/ajax/merchantMap/856752"></div>
# </div>
# <div class="merchant-mlr merchant-mlr-mobile">
# <ul class="mlr mlr--merchant">
# <!-- here too -->
# <li class="mlr__item mlr__item--more mlr__item--phone">
# <a class="mlr__item__cta jsMlrMenu" data-analytics-placeholder='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Call - Reveal Phone Number","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"revealphonenumber","page_section":"Merchant Page - Top Bar"}' href="#">
# <div class="messageIcon">
# <span class="ypicon ypicon-phone mlr__icon"></span><span class="messageText">Phone Number</span></div>
# </a>
# <ul class="mlr__submenu jsMlrSubMenu">
# <li class="mlr__submenu__item"><span class="mlr__sub-text" itemprop="telephone" tabindex="0">226-781-1101</span><span class="mlr__label">Primary</span></li></ul>
# </li>
# <li class="mlr__item mlr__item--message hide-print">
# <a class="ypModal mlr__item__cta merchantMessage jsMerchantMessage" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Message","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_2","lk_name":"message-step1","page_section":"Merchant Page - Top Bar"}' data-mid="856752" data-modal-url="https://www.yellowpages.ca/ajax/messaging/merchantMessageDialog?id=856752&amp;name=Jewel+Of+India+Restaurant+Inc&amp;address=390+Richmond+St%2C+London%2C+ON+N6A+3C7&amp;requestSource&amp;lang=en=merchant" data-target="#jsModalContainer" data-toggle="ajax-modal" href="javascript:void(0);">
# <div class="messageIcon"><span class="ypicon ypicon-message-bubble mlr__icon"></span><span class="newMessage">Message</span></div>
# </a>
# </li>
# <li class="mlr__item mlr__item--direction hide-print">
# <a class="mlr__item__cta" data-analytics='{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp","event_name":"click - Directions - Intent","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"directions-step1","page_section":"Merchant Page - Top Bar"}' href="/merchant/directions/856752/?what=Restaurants&amp;where=London+ON" rel="nofollow" title="Get directions">
# <div class="messageIcon"><span class="ypicon ypicon-getDirection mlr__icon"></span><span class="newMessage">Directions</span></div>
# </a>
# </li>
# <li class="mlr__item mlr__item--website mlr__item--more">
# ...
# "next": {"lk_pos":"in_mp_photovideooverlay","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_area":"mid","lk_name":"next_top"}
# }
# </script>
# <script id="jsAnalyticsVideosTranscript" type="application/json">
# {
# ".jsTglScript": {"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"in_mp_photovideooverlay","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"ADAPT","lk_name":"viewtranscript"}
# }
# </script>
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/galleryImages.js" type="text/javascript"></script><script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/galleryImagesExtra.js" type="text/javascript"></script><script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/galleryDesktop.js" type="text/javascript"></script><script type="text/javascript">
# window.fbAsyncInit = function () {
# FB.init({
# appId: "1004441262966232",
# status: true,
# cookie: true,
# xfbml: true,
# oauth: true
# });
# };
# (function (d) {
# var js, id = 'facebook-jssdk';
# if (d.getElementById(id)) {
# return;
# }
# js = d.createElement('script');
# js.id = id;
# js.async = true;
# js.src = "//connect.facebook.net/en_US/all.js";
# d.getElementsByTagName('head')[0].appendChild(js);
# }(document));
# </script>
# <script class="jsMerchantInappropriatePhotoConfig" type="application/json">
# {
# "inappropriatePhotoModalUrl": "/ajax/inappropriateReviewModal?source=photo",
# "galleryFlags": [{"reviewId":null,"isFlaggable":false},{"reviewId":null,"isFlaggable":false},{"reviewId":null,"isFlaggable":false}]
# }
# </script>
# <script type="text/javascript">
# $YPCA.deferJsV2('//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/yellowMerchant_defer.js');</script>
# <script id="analytics-resource-restricted" type="application/json">
# {
# "age_restricted_warning" : {"event_name":"impression - age restricted - warning","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"age_restricted_warning"},
# "age_restricted_close" : {"event_name":"click - age restricted - close","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"age_restricted_close"},
# "age_restricted_no" : {"event_name":"click - age restricted - no","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"age_restricted_no"},
# "age_restricted_yes" : {"event_name":"click - age restricted - yes","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"age_restricted_yes"}
# }
# </script>
# <script id="review_notification_email" type="application/json">
# {
# "review_notification_email" : {"event_name":"review notification email","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"review_notification_email"}
# }
# </script>
# <script id="view_suggest_update" type="application/json">
# {
# "impression_suggest_update_warning" : {"event_name":"impression  - Suggest an Update - warning","lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_name":"impression_suggest_update_warning"}
# }
# </script>
# <script id="autocompleteTemplate" type="text/x-handlebars-template">
# <span {{#if code}} class="disambiguation" {{else}} class="tt__category" {{/if}}>
# {{#if code}}
# {{alt}}
# {{else}}
# {{value}}
# {{/if}}
# </span>
# {{#if merchantDetail}}<span class="ypicon ypicon-business-unique business-unique"></span>{{/if}}
# </script>
# <script id="autocompleteTemplateForCurrentLocation" type="text/x-handlebars-template">
# <div id="currentLocationForTypeahead" class="suggested-location__current jsCurrentLocationForTypeahead">
# <ul class="suggested-location__list search-dropdown__list">
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem jsSuggestedLocationItemCurrent tt-suggestion tt-selectable" data-currentlocation-selected="1" data-label="Current Location" data-label-unresolvedlocation="Could not locate you" data-label-attemptlocate="Attempting to locate you">
# <span class="suggested-location__list__item--loading"></span>
# <span class="ypicon ypicon-curloc be-relative"></span>
# <span class="jsCurrentLocationItem">{{ currentLocation }}</span>
# </li>
# </ul>
# </div>
# </script>
# <script id="whereFieldTemplate" type="text/x-handlebars-template">
# {{#if currentLocation}}
# <div id="suggestedLocationDropdown" class="suggested-location search-dropdown jsSuggestedLocation">
# <div class="suggested-location__wrapper search-dropdown__wrapper">
# <div class="suggested-location__wrapper--inner search-dropdown__wrapper--inner">
# <div class="suggested-location__wrapper__inside search-dropdown__wrapper__inside">
# <div id="currentLocation" class="suggested-location__current">
# <ul class="suggested-location__list search-dropdown__list">
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem jsSuggestedLocationItemCurrent tt-suggestion tt-selectable" data-currentlocation-selected="1" data-label="Current Location" data-label-unresolvedlocation="Could not locate you" data-label-attemptlocate="Attempting to locate you">
# <span class="suggested-location__list__item--loading"></span>
# <span class="ypicon ypicon-curloc be-relative"></span>
# <span class="jsCurrentLocationItem">{{ currentLocation }}</span>
# </li>
# </ul>
# </div>
# <div id="previousLocation" class="suggested-location__previous jsPreviousLocation">
# <h2 class="suggested-location__title search-dropdown__title jsSuggestedPreviousLocationListLabel">
# <span class="search-dropdown__title--label suggested-location__title--label">
# {{#if previouslySearched}}
# Previous Locations
# {{else}}
# Previous Location
# {{/if}}
# </span>
# {{#if previouslySearched}}
# <span class="search-dropdown__title--button suggested-location__title--button jsClearSearchedLocation" role="button">Clear all</span>
# {{/if}}
# </h2>
# <div class="suggested-location__placeholder__animation">&nbsp;</div>
# <ul class="suggested-location__list search-dropdown__list jsSuggestedLocationList">
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem">{{ geoIpLocation }}</li>
# {{#if previouslySearched}}
# {{#each previouslySearched}}
#
# {{#ifCond ../geoIpLocation '!==' this }}
# <li class="suggested-location__list__item search-dropdown__list__item jsSuggestedLocationItem">{{ this }}</li>
# {{/ifCond}}
# {{/each}}
# {{/if}}
# </ul>
# <p class="suggested-location__message_success jsSuggestedLocationMsgSuccess">Your recent locations have been cleared</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# {{/if}}
# </script>
# <script class="jsWhatFieldTemplate" id="whatFieldTemplate" type="text/x-handlebars-template">
# {{#if previouslySearched}}
# <div id="previousSearchesDropdown" class="previous-searches search-dropdown jsPreviousSearch">
# <div class="previous-searches__wrapper search-dropdown__wrapper">
# <div class="previous-searches__wrapper--inner search-dropdown__wrapper--inner jsPreviousSearchInner">
# <div class="previous-searches__wrapper__inside search-dropdown__wrapper__inside">
# <h2 class="previous-searches__title search-dropdown__title">Previous search(es)<span class="search-dropdown__title--button suggested-location__title--button jsClearSearchedWhat" role="button">Clear all</span>
# </h2>
# <ul class="previous-searches__list search-dropdown__list jsPreviousSearchList">
# {{#each previouslySearched}}
# <li class="previous-searches__list__item search-dropdown__list__item jsPreviousSearchItem">{{ this }}</li>
# {{/each}}
# </ul>
# </div>
# </div>
# </div>
# </div>
# {{/if}}
# </script>
# <script id="feature-where-smart-autocomplete" type="application/json">
# {
# "isWhereSuggestedLocation" : true,
# "deleteCookiesURL" : "/ajax/utilities/eraseRecentWhereSearches",
# "messages": {
# "locationLabel": "Current Location",
# "locationNearYouLabel": "Current location near you in",
# "currentLocationLabelForMap" : "My location"
# }
# }
# </script>
# <script class="jsProxyYidConfig" id="proxy-yid-config" type="application/json">
# {
# "otherSideBaseUrl" : "https://www.pagesjaunes.ca/proxy",
# "otherSideBaseUrlPasswordless" : "https://www.pagesjaunes.ca/proxyPasswordLess"
# }
# </script>
# <script class="jsSuggestedLocationsConfig" type="application/json">
# {
# "suggestedLocationLabel" : "Suggested locations"
# }
# </script>
# <script class="jsPageConfigurationResource" id="page-configuration-resource" type="application/json">
# {
# "mapSearch": false,
# "isCobrand": false,
# "cookieDomain": ".yellowpages.ca",
# "analytics": {
# "mapLocation": {"lk_pos":"in_listing","event_name":"click - View My Location","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_area":"left_2","lk_name":"locate-me"},
# "zoomedIn": {"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"mapanddirections","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"zoom-in"},
# "zoomedOut": {"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_pos":"mapanddirections","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"left_1","lk_name":"zoom-out"}
# }
# }
# </script>
# <script id="search-action-resource" type="application/json">
# {
# "currentLanguage": "en",
# "currentLocation": "Toronto, ON",
# "defaultSearch": "/search/si/1/{{what}}/{{where}}",
# "personSearch": {
# "en": "http://www.canada411.ca/search/si/1/{{what}}/{{where}}/",
# "fr": "http://www.fr.canada411.ca/search/si/1/{{what}}/{{where}}/"
# },
# "geolocationMaxAgeConfiguration": "600000",
# "isExternalReferrer": "false",
# "maskedLocationLabel": "Near me",
# "maskedLocationLabelGetDirections": "My location"
# }
# </script>
# <script class="jsIsSafariOrIE" type="application/json">
# {
# "safariOrIE" : "false"
# }
# </script>
# <script data-analytics-resource="true" id="autocomplete-analytics-resource" type="application/json">
# {"autocomplete_what":{"context":{},"binding":"autocomplete_what","data-analytics":{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_what_user":"Jewel Of India Restaurant Inc","lk_pos":"in_autocomplete","lk_what_ac_idx":"-1","lk_what_ac_txt":"","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_area":"in_autocomplete","lk_name":"busnameautocomplete-serp"}},"autocomplete_where":{"context":{},"binding":"autocomplete_where","data-analytics":{"lk_listing_id":"856752","lk_se_id":"8044579e-1daf-45d0-adb2-10ed0017331e_SmV3ZWwgT2YgSW5kaWEgUmVzdGF1cmFudCBJbmM_TG9uZG9uIE9O","lk_where_ac_txt":"","lk_where_ac_idx":"-1","lk_product":"L2","lk_directory_heading":[{"092922":[{"01125710":"1"},{"00280450":"1"},{"02000044":"1"},{"00000000":"1"}]}],"lk_where_user":"London ON"}}}</script>
# <!-- comScore Identifier: comscorekw=RESTAURANTS%20%26%20BARS -->
# <script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/tags.js" type="text/javascript"></script><script charset="UTF-8" src="//static.yellowpages.ca/ypca/ypui-6.69.0.0-20220823.0703/resources/static/gpt.js" type="text/javascript"></script><script id="jsGenConfig" type="application/json">
# {
# "cookieDomain" : ".yellowpages.ca"
# }
# </script>
# <script async="" src="//cdn.districtm.ca/merge/merge.v4.2.103991.js"></script>
# <script type="text/javascript">
# if(aJsFiles.length > 0) {
# if (window.fetch && typeof window.fetch !== 'undefined') {
# fetchInject(aJsFiles.slice(1, aJsFiles.length),fetchInject([aJsFiles[0]]));
# } else {
# $YPCA.loopDeferScript(aJsFiles);
# }
# }
# </script>
# <!-- Global site tag (gtag.js) - Google Ads: AW-794878240 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-794878240"></script>
# <!-- Global site tag (gtag.js) - Google Analytics:  -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-126563938-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
#
# function gtag() {
# dataLayer.push(arguments);
# }
#
# gtag('js', new Date());
# // Sending the pageview to multiple Google Analytics properties by specifying a config for each property
# gtag('config', 'AW-794878240');
# gtag('config', 'UA-126563938-1');
# </script>
# <script>
# jQuery(document).ready(function ($) {
# jQuery('body').on('mousedown touchstart', '[data-analytics]', function (e) {
# var targetElement = jQuery(e.currentTarget),
# tagName = targetElement.prop("tagName");
# if (tagName !== "OPTION" && tagName !== "SELECT") {
# var event = targetElement.attr('data-analytics-event');
# if (!YPCA.Utils.isDefined(event) || event === 'mousedown') {
# var analyticsJson = YPCA.Utils.parseJSONGracefully(targetElement.attr('data-analytics'));
# if (YPCA.Utils.isDefined(analyticsJson) && analyticsJson.hasOwnProperty('lk_name')) {
# gtag_report_conversion(analyticsJson.lk_name);
# }
# }
# }
# });
# });
# </script>
# <script>
# function detectMobile() {
# return false;
# }
#
# function sendTo(lkName) {
# var sendTo;
# switch (lkName) {
# case "email-confirm":
# if (detectMobile()) {
# sendTo = "-cMnCImb2I";
# } else {
# sendTo = "4o8cCPGR2I";
# }
# break;
# case "message-confirm":
# if (detectMobile()) {
# sendTo = "KYt_CL-b2I";
# } else {
# sendTo = "JJGoCMWEyY";
# }
# break;
# case "orderonline-confirm":
# if (detectMobile()) {
# sendTo = "Lmu7CPGa2I";
# } else {
# sendTo = "y67RCKKZ2I";
# }
# break;
# case "reserve-confirm":
# if (detectMobile()) {
# sendTo = "KQqCCKK84Y";
# } else {
# sendTo = "ZmjWCLGZ2I";
# }
# break;
# case "reserve-step1-failed":
# if (detectMobile()) {
# sendTo = "LrMPCIid2I";
# } else {
# sendTo = "JPu6CIeZ2I";
# }
# break;
# case "reserve-step1failed":
# sendTo = "DVJtCIiGyY";
# break;
# case "revealphonenumber":
# sendTo = "LD5-COyY2I";
# break;
# case "directions-step1":
# sendTo = "2YpFCNq44Y";
# break;
# case "directions-confirm":
# sendTo = "FO8bCMS64Y";
# break;
# case "mobilecall":
# sendTo = "sYlACOP-yI";
# break;
# default:
# return null;
# }
# return "AW-794878240/" + sendTo + "YBEKDCg_sC";
# }
#
# function gtag_report_conversion(lkName) {
# var account = sendTo(lkName);
# if (account) {
# var jsfunction = function () {
# lkName;
# }
# gtag('event', 'conversion', {
# 'send_to': account,
# 'event_callback': jsfunction
# });
# }
#
# return false;
# }
#
# </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","licenseKey":"d901b4dcbe","agent":"","beacon":"bam.nr-data.net","applicationTime":313,"applicationID":"498805584","transactionName":"YgQEYUFVV0IDB0wNDltONUVBXVdWIQtWEBNaDQpQQRtbRBFLQxQTWhcPW1BRRB4ZB1EQGEhOHVdGR1BfBxdLKgBYBBsaSFhQQhYtXBlBHSYjYRo=","queueTime":0}</script></body>
# </html>

# %%
#article
article = soup2.find('article', {'class':"merchant__item merchant__teaser"}).get_text().strip()
article
# Out:
# 'Take your taste buds on a trip around the world with Jewel of India Restaurant Inc. Located in London, we serve dishes such as biryani, dupiaza, dansak, tandoori, vindaloo and much more. Finish your meal with one of our succulent and signature Indian desserts. To reserve a table, call us today.'

# %% [markdown]
# ### First page

# %%
names = []
addresses = []
ratings = []
hrefs = []

for item in results:
    try:
        names.append(item.img['alt'])
    except:
        names.append('n/a')
        
    try:
        addresses.append(item.find('span', {'class':"jsMapBubbleAddress"}).get_text())
    except:
        addresses.append('n/a')
        
    try:
        ratings.append(item.find('a', {'class': "listing__ratings__count listing__link"}).get_text().strip())
    except:
        ratings.append('n/a')
    
    try:
        hrefs.append(item.find('a', {'class': "listing__name--link listing__link jsListingName"})['href'])
    except:
        hrefs.append('n/a')

# %%
links = []
for href in hrefs:
    try:       
        links.append(urljoin(url, href))
    except:
        links.append('n/a')

# %%
restaurants_page1 = pd.DataFrame({'Names': names, 'Addresses' : addresses, 'Ratings' : ratings, 
                                  'Links' : links})

# %%
restaurants_page1.head()
# Out:
#                                          Names             Addresses Ratings  \
# 0  Jewel Of India Restaurant Inc - Restaurants       390 Richmond St    (17)
# 1   Wille's Catering and Takeout - Restaurants         630 Dundas St     (8)
# 2        Little Panda Restaurant - Restaurants  389 Wharncliffe Rd S    (10)
# 3                Irene's Seafood - Restaurants    315A Wellington Rd     (8)
# 4        Michael's On The Thames - Restaurants             1 York St    (53)
#
#                                                Links
# 0  https://www.yellowpages.ca/bus/Ontario/London/...
# 1  https://www.yellowpages.ca/bus/Ontario/London/...
# 2  https://www.yellowpages.ca/bus/Ontario/London/...
# 3  https://www.yellowpages.ca/bus/Ontario/London/...
# 4  https://www.yellowpages.ca/bus/r/Ontario/Londo...

# %% [markdown]
# ### Pagination

# %%
names_ = []
addresses_ = []
ratings_ = []
hrefs_ = []

for i in range(1,32):    
    website_ = 'https://www.yellowpages.ca/search/si/' + str(i) + '/Restaurants/London+ON'
    response_ = requests.get(website_)
    soup_ = BeautifulSoup(response_.content, 'html.parser')
    results_ = soup_.find_all('div', {'class':"listing"})
    
    for item in results_:
        try:
            names_.append(item.img['alt'])
        except:
            names_.append('n/a')
        
        try:
            addresses_.append(item.find('span', {'class':"jsMapBubbleAddress"}).get_text())
        except:
            addresses_.append('n/a')
        
        try:
            ratings_.append(item.find('a', {'class': "listing__ratings__count listing__link"}).get_text().strip())
        except:
            ratings_.append('n/a')
    
        try:
            hrefs_.append(item.find('a', {'class': "listing__name--link listing__link jsListingName"})['href'])
        except:
            hrefs_.append('n/a')

# %%
links_ = []
for item in hrefs_:
    try:       
        links_.append(urljoin(url, item))
    except:
        links_.append('n/a')

# %%
len(links_)
# Out:
# 1065

# %%
articles_ = []
for item in links_: 
    try:
        response_3 = requests.get(item)
        soup_3 = BeautifulSoup(response_3.content, 'html.parser')
        articles_.append(soup_3.find('article', {'class':"merchant__item merchant__teaser"}).get_text().strip())
    except:
        articles_.append('n/a')

# %%
all_restaurants_London = pd.DataFrame({'Names': names_, 'Addresses' : addresses_, 'Ratings' : ratings_, 
                                  'Articles': articles_, 'Links' : links_})

# %%
all_restaurants_London.head()
# Out:
#                                          Names             Addresses Ratings  \
# 0  Jewel Of India Restaurant Inc - Restaurants       390 Richmond St    (17)
# 1   Wille's Catering and Takeout - Restaurants         630 Dundas St     (8)
# 2        Little Panda Restaurant - Restaurants  389 Wharncliffe Rd S    (10)
# 3                Irene's Seafood - Restaurants    315A Wellington Rd     (8)
# 4        Michael's On The Thames - Restaurants             1 York St    (53)
#
#                                             Articles  \
# 0  Take your taste buds on a trip around the worl...
# 1  Come enjoy a delightful meal at Willie's Cafe....
# 2  Too tired to cook? Call Little Panda Restauran...
# 3  English Style Fish & Chips Specializing in Hal...
# 4  Enjoy superb continental cuisine in the relaxi...
#
#                                                Links
# 0  https://www.yellowpages.ca/bus/Ontario/London/...
# 1  https://www.yellowpages.ca/bus/Ontario/London/...
# 2  https://www.yellowpages.ca/bus/Ontario/London/...
# 3  https://www.yellowpages.ca/bus/Ontario/London/...
# 4  https://www.yellowpages.ca/bus/r/Ontario/Londo...

# %% [markdown]
# ### Data Cleaning

# %%
all_restaurants_London['Ratings'] = all_restaurants_London['Ratings'].apply(lambda x: x.replace('(',"").
                                                                            replace(')',""))
all_restaurants_London.head()
# Out:
#                                          Names             Addresses Ratings  \
# 0  Jewel Of India Restaurant Inc - Restaurants       390 Richmond St      17
# 1   Wille's Catering and Takeout - Restaurants         630 Dundas St       8
# 2        Little Panda Restaurant - Restaurants  389 Wharncliffe Rd S      10
# 3                Irene's Seafood - Restaurants    315A Wellington Rd       8
# 4        Michael's On The Thames - Restaurants             1 York St      53
#
#                                             Articles  \
# 0  Take your taste buds on a trip around the worl...
# 1  Come enjoy a delightful meal at Willie's Cafe....
# 2  Too tired to cook? Call Little Panda Restauran...
# 3  English Style Fish & Chips Specializing in Hal...
# 4  Enjoy superb continental cuisine in the relaxi...
#
#                                                Links
# 0  https://www.yellowpages.ca/bus/Ontario/London/...
# 1  https://www.yellowpages.ca/bus/Ontario/London/...
# 2  https://www.yellowpages.ca/bus/Ontario/London/...
# 3  https://www.yellowpages.ca/bus/Ontario/London/...
# 4  https://www.yellowpages.ca/bus/r/Ontario/Londo...

# %%
all_restaurants_London.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1065 entries, 0 to 1064
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Names      1065 non-null   object
#  1   Addresses  1065 non-null   object
#  2   Ratings    1065 non-null   object
#  3   Articles   1065 non-null   object
#  4   Links      1065 non-null   object
# dtypes: object(5)
# memory usage: 41.7+ KB

# %%
my_data = all_restaurants_London.replace('n/a', np.nan)
my_data = my_data.dropna(how='any', axis=0, thresh=3)
my_data.head()
# Out:
#                                          Names             Addresses Ratings  \
# 0  Jewel Of India Restaurant Inc - Restaurants       390 Richmond St      17
# 1   Wille's Catering and Takeout - Restaurants         630 Dundas St       8
# 2        Little Panda Restaurant - Restaurants  389 Wharncliffe Rd S      10
# 3                Irene's Seafood - Restaurants    315A Wellington Rd       8
# 4        Michael's On The Thames - Restaurants             1 York St      53
#
#                                             Articles  \
# 0  Take your taste buds on a trip around the worl...
# 1  Come enjoy a delightful meal at Willie's Cafe....
# 2  Too tired to cook? Call Little Panda Restauran...
# 3  English Style Fish & Chips Specializing in Hal...
# 4  Enjoy superb continental cuisine in the relaxi...
#
#                                                Links
# 0  https://www.yellowpages.ca/bus/Ontario/London/...
# 1  https://www.yellowpages.ca/bus/Ontario/London/...
# 2  https://www.yellowpages.ca/bus/Ontario/London/...
# 3  https://www.yellowpages.ca/bus/Ontario/London/...
# 4  https://www.yellowpages.ca/bus/r/Ontario/Londo...

# %%
my_data.tail()
# Out:
#                                           Names             Addresses Ratings  \
# 1051          Momos at the Market - Restaurants                London     NaN
# 1053  Wok Box Fresh Asian Kitchen - Restaurants  3099 Wonderland Rd S     NaN
# 1054          Kelsey's Restaurant - Restaurants    900 Oxford St East     NaN
# 1056           Crabby's BBQ Shack - Restaurants                   NaN     NaN
# 1058                  Shiny Panes - Restaurants                London     NaN
#
#                                                Articles  \
# 1051                                                NaN
# 1053                                                NaN
# 1054                                                NaN
# 1056  Come enjoy a delightful creation at Crabby's B...
# 1058                                                NaN
#
#                                                   Links
# 1051  https://www.yellowpages.ca/bus/Ontario/London/...
# 1053  https://www.yellowpages.ca/bus/Ontario/Wok-Box...
# 1054  https://www.yellowpages.ca/bus/Ontario/Kelsey-...
# 1056  https://www.yellowpages.ca/bus/Ontario/Crabby-...
# 1058  https://www.yellowpages.ca/bus/Ontario/London/...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1029 entries, 0 to 1058
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Names      1029 non-null   object
#  1   Addresses  1022 non-null   object
#  2   Ratings    308 non-null    object
#  3   Articles   627 non-null    object
#  4   Links      1029 non-null   object
# dtypes: object(5)
# memory usage: 48.2+ KB

# %%
my_data.to_excel('all_restaurants_London.xlsx', index = False)
